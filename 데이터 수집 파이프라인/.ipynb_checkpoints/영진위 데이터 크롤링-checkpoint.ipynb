# %% [markdown]
# # api 크롤링
#
# 기존의 크롤링 방식은
#
# 1. 내가 직접 홈페이지에 브라우저를 켜서 접근하거나(selenium)
#
# 혹은
#
# 2. 파이썬 자체적으로 호출을 요청해서(requests)
#
# 데이터를 가지고 오는 방식이엇습니다.
#
# 이 방식은 서버에 부하가 많이 갈 뿐더러 나에게 필요없는 데이터까지 한 번에 호출해서 가져오는 문제가 있습니다.
#
# 따라서 서비스 제공자측에서는 서버 부하를 줄이고, 사용자에게 맞춤형을 데이터를 제공하기 위해 api 서버를 운영합니다.
#
# api 서버는 인가된 데이터만을 개발자에게 넘겨서 서버도 안정적으로 유지하며(횟수 제한이 있는 사이트도 많습니다. 라이엇 데이터는 1초에 5회, 2분에 100회로 제한됩니다.)
#
# 필요없는 동영상자료나 그림자료를 호출하지 않으므로 트래픽을 줄일 수 있습니다.
#
# api 서버 접근시 보통 urllib.request를 이용하게 됩니다.

# %%
# 사이트에 자료 요청
import urllib.request
# json 데이터 핸들링
import json
# DataFrame 자료형 활용
import pandas as pd
# json 데이터를 pandas DataFrame으로 변환
from pandas.io.json import json_normalize

# %% [markdown]
# # 영진위 api 신청
#
# http://www.kobis.or.kr/kobisopenapi/homepg/main/main.do
#
# 1. 접속 후 가입 및 로그인
#
# 2. 키발급 탭에서 키 발급하기
#
# 3. 요청 api종류 보고 요청양식 및 데이터 확인하기

# %%
api_key = "cf987f1dd58a13d0f7e751c8e0ed1043" # 발급받은 키
request_data = "20220622"
url ="http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=%s" % (api_key, request_data)
print(url)
# Out:
# http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=cf987f1dd58a13d0f7e751c8e0ed1043&targetDt=20220622

# %% [markdown]
# # json 데이터를 팬더스 데이터프레임으로 변환
#
# api 데이터는 보통 json(JavaScript Object Notation) 타입으로 받아집니다.
#
# 쉽게 말하면 자바스크립트 데이터를 전달하기 좋게 설정한 자료형인데
#
# 파이썬의 딕셔너리와 거의 같다고 보시면 됩니다.
#
# 따라서 json 데이터를 팬더스 데이터로 변환한다는 것은 사실상
#
# 딕셔너리 데이터를 팬더스 데이터프레임으로 변환하는것입니다.

# %%
# 위의 url 변수를 이용해 데이터를 요청합니다.
r = urllib.request.urlopen(url)
# 요청 페이지의 결과 데이터를 파이썬 내부 데이터로 바꿉니다.
json_raw = r.read()

# %%
# b '~~~~~~~~~~'로 시작하는 이 데이터는 파이썬에서 byte자료형으로 처리되고
# 데이터프레임으로는 바로 변환이 불가능합니다.
json_raw
# Out:
# b'{"boxOfficeResult":{"boxofficeType":"\xec\x9d\xbc\xeb\xb3\x84 \xeb\xb0\x95\xec\x8a\xa4\xec\x98\xa4\xed\x94\xbc\xec\x8a\xa4","showRange":"20220622~20220622","dailyBoxOfficeList":[{"rnum":"1","rank":"1","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20194376","movieNm":"\xed\x83\x91\xea\xb1\xb4: \xeb\xa7\xa4\xeb\xb2\x84\xeb\xa6\xad","openDt":"2022-06-22","salesAmt":"1976049530","salesShare":"54.3","salesInten":"1976049530","salesChange":"100","salesAcc":"2716938360","audiCnt":"188312","audiInten":"188312","audiChange":"100","audiAcc":"253016","scrnCnt":"1975","showCnt":"9158"},{"rnum":"2","rank":"2","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"
xa0 \xec\x8b\xb6\xeb\x8b\xa4","openDt":"2022-04-27","salesAmt":"5090000","salesShare":"0.1","salesInten":"3590000","salesChange":"239.3","salesAcc":"3912819280","audiCnt":"1015","audiInten":"715","audiChange":"238.3","audiAcc":"409303","scrnCnt":"3","showCnt":"4"},{"rnum":"9","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20199500","movieNm":"\xeb\x9c\xa8\xea\xb1\xb0\xec\x9a\xb4 \xed\x94\xbc","openDt":"2022-03-23","salesAmt":"5000000","salesShare":"0.1","salesInten":"2500000","salesChange":"100","salesAcc":"3776252970","audiCnt":"1000","audiInten":"500","audiChange":"100","audiAcc":"396788","scrnCnt":"4","showCnt":"5"},{"rnum":"10","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20212783","movieNm":"\xeb\xa1\x9c\xec\x8a\xa4\xed\x8a\xb ...

# %%
# 바이트자료형임을 확인
type(json_raw)
# Out:
# bytes

# %%
# 따라서 utf-8 형식으로 고쳐줘야 합니다. decode()를 이용합니다.
# encode => 우리가 쓰는 문자를 컴퓨터가 쓰는 형태로 변환
# decode => 컴퓨터가 쓰는 형태의 문자를 우리가 쓰는 형태로 변환
json_utf8 = json_raw.decode("utf-8")

# %%
# 딕셔너리 구조를 유지하고 있는 문자로 변환됨
type(json_utf8)
# Out:
# str

# %%
json_utf8
# Out:
# '{"boxOfficeResult":{"boxofficeType":"일별 박스오피스","showRange":"20220622~20220622","dailyBoxOfficeList":[{"rnum":"1","rank":"1","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20194376","movieNm":"탑건: 매버릭","openDt":"2022-06-22","salesAmt":"1976049530","salesShare":"54.3","salesInten":"1976049530","salesChange":"100","salesAcc":"2716938360","audiCnt":"188312","audiInten":"188312","audiChange":"100","audiAcc":"253016","scrnCnt":"1975","showCnt":"9158"},{"rnum":"2","rank":"2","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20224882","movieNm":"마녀(魔女) Part2. The Other One","openDt":"2022-06-15","salesAmt":"836476290","salesShare":"23.0","salesInten":"-253649090","salesChange":"-23.3","salesAcc":"18226409650","audiCnt":"82691","audiInten":"-25491","audiChange":"-23.6","audiAcc":"1769461","scrnCnt":"976","showCnt":"3502"},{"rnum":"3","rank":"3","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20204548","movieNm":"범죄도시 2","openDt":"2022-05-18","salesAmt":"577713370","salesShare":"15.9","salesInten":"-158550060","salesChange":"-21.5","salesAcc":"120660923940","audiCnt":"57874","audiInten":"-15988","audiChange":"-21.6","audiAcc":"11671470","scrnCnt":"774","showCnt":"2531"},{"rnum":"4","rank":"4","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20206257","movieNm":"브로커","openDt":"2022-06-08","salesAmt":"96967760","salesShare":"2.7","salesInten":"-120719520","salesChange":"-55.5","salesAcc":"11616358360","audiCnt":"9992","audiInten":"-12366","audiChange":"-55.3","audiAcc":"1160649","scrnCnt":"449","showCnt":"674"},{"rnum":"5","rank":"5","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20223839","movieNm":"버즈 라이트이어","openDt":"2022-06-15","salesAmt":"34719200","salesShare":"1.0","salesInten":"-99957740","salesChange":"-74.2","salesAcc":"2493961690","audiCnt":"3952","audiInten":"-8455","audiChange":"-68.1","audiAcc":"233278","scrnCnt":"287","showCnt":"375"},{"rnum":"6","rank":"6","rankInten":"-1","rankOldAndNew":"OLD","movieCd":"20206061","movieNm":"쥬라기 월드: 도미니언","openDt":"2022-06-01","salesAmt":"21223800","salesShare":"0.6","salesInten":"-76011160","salesChange":"-78.2","salesAcc":"28777337910","audiCnt":"2271","audiInten":"-7685","audiChange":"-77.2","audiAcc":"2788530","scrnCnt":"117","showCnt":"141"},{"rnum":"7","rank":"7","rankInten":"0","rankOldAndNew":"NEW","movieCd":"20224757","movieNm":"룸 쉐어링","openDt":"2022-06-22","salesAmt":"13283560","salesShare":"0.4","salesInten":"13283560","salesChange":"100","salesAcc":"33442560","audiCnt":"1586","audiInten":"1586","audiChange":"100","audiAcc":"3937","scrnCnt":"122","showCnt":"190"},{"rnum":"8","rank":"8","rankInten":"12","rankOldAndNew":"OLD","movieCd":"20178501","movieNm":"니 부모 얼굴이 보고 싶다","openDt":"2022-04-27","salesAmt":"5090000","salesShare":"0.1","salesInten":"3590000","salesChange":"239.3","salesAcc":"3912819280","audiCnt":"1015","audiInten":"715","audiChange":"238.3","audiAcc":"409303","scrnCnt":"3","showCnt":"4"},{"rnum":"9","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20199500","movieNm":"뜨거운 피","openDt":"2022-03-23","salesAmt":"5000000","salesShare":"0.1","salesInten":"2500000","salesChange":"100","salesAcc":"3776252970","audiCnt":"1000","audiInten":"500","audiChange":"100","audiAcc":"396788","scrnCnt":"4","showCnt":"5"},{"rnum":"10","rank":"9","rankInten":"5","rankOldAndNew":"OLD","movieCd":"20212783","movieNm":"로스트 시티","openDt":"2022-04-20","salesAmt":"5000000","salesShare":"0.1","salesInten":"2500000","salesChange":"100","salesAcc":"1006394850","audiCnt":"1000","audiInten":"500","audiChange":"100","audiAcc":"109848","scrnCnt":"4","showCnt":"5"}]}}'

# %%
# json.loads(딕셔너리 형태의 문자열 자료)
# 딕셔너리 형태로 적힌 문자열 자료를 딕셔너리형으로 변환
json_complete = json.loads(json_utf8)

# %%
# 딕셔너리(json) 변환 완료 확인
type(json_complete)
# Out:
# dict

# %%
# json_normalize(딕셔너리 자료)
# 딕셔너리 자료를 데이터프레임 형태로 변환해줌
pd.json_normalize(json_complete)
# Out:
#   boxOfficeResult.boxofficeType boxOfficeResult.showRange  \
# 0                      일별 박스오피스         20220622~20220622
#
#                   boxOfficeResult.dailyBoxOfficeList
# 0  [{'rnum': '1', 'rank': '1', 'rankInten': '0', ...

# %%
# boxOfficeResult.dailyBoxOfficeList 컬럼 내부에 딕셔너리가여럿 묶인 리스트가 보이므로
# boxOfficeResult.dailyBoxOfficeList 컬럼을 타겟으로 데이터프레임화 합니다.
box_result = pd.json_normalize(json_complete['boxOfficeResult']['dailyBoxOfficeList'])

# %%
# json_normalize()는 pd.DataFrame() 으로 대체 가능합니다.
pd.DataFrame(json_complete)
# Out:
#                                                       boxOfficeResult
# boxofficeType                                                일별 박스오피스
# dailyBoxOfficeList  [{'rnum': '1', 'rank': '1', 'rankInten': '0', ...
# showRange                                           20220622~20220622

# %% [markdown]
# API 크롤링으로 서비스 제공시
#
# 사용자가 조회할때마다 매번 API서버에 요청을 넣어서 데이터를 가져오면
#
# 호출횟수를 금방 소모 하게 됩니다.
#
# 따라서, 보통 API를 활용한 서비스는 미리 데이터를 DB에 적재해놓고
#
# 사용자가 요청 시 내 DB에 있는 데이터를 우선적으로 보여주고, 없으면 외부서버에
#
# 요청해서 내 DB에 INSERT한 다음 다시 내 DB데이터를 사용자에게 보여줍니다.

# %%
url
# Out:
# 'http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=cf987f1dd58a13d0f7e751c8e0ed1043&targetDt=20220622'

# %% [markdown]
# 날짜 데이터는 28일까지인 달(2월), 30일까지인 달, 31일까지인 달 들이 있어서
#
# 단순히 문자열에 1씩 더하거나 날짜처리를 하기도 어렵고
#
# 위의 처리를 다 했다고 해도 4년에 1번 윤달이 있습니다(2월 29일)
#
# 그래서, 날짜는 전적으로 날짜데이터를 이용해 처리해야만 합니다.
#
# 파이썬에서는 datatime을 이용해 처리합니다.(자바는 java.util.Data를 써서 처리)

# %%
import time
import datetime # 파이썬 날짜 자료형

# %%
start_datetime = datetime.datetime(2021, 8, 9) # 년 월 일 순으로 넣어줍니다.
# 형식 바꾸기
target_date = start_datetime.strftime('%Y%m%d') # 영진위 형식으로 변경
print(target_date)
# 날짜 하루 올리기
next_datetime = start_datetime + datetime.timedelta(days=1)
next_datetime
# Out:
# 20210809
# datetime.datetime(2021, 8, 10, 0, 0)

# %%
target_dates = ['20220620', '20220621', '20220622']
# 날짜는 시작날짜와 + 며칠 을 처리할지 결정할 수 있습니다.
# 3일치 데이터를 얻은 다음 to_csv나 to_excel로 저장해주세요.

# 반복문과 append를 이용해서 3일치 데이터를 요청해서 합쳐보세요.
# target_date 컬럼에 조회 날짜를 추가해주세요.
# 빈 데이터프레임을 하나 생성해놓고(pd.DataFrame())
merged_data = pd.DataFrame()
for date in target_dates:
    api_key = "cf987f1dd58a13d0f7e751c8e0ed1043" # 발급받은 키
    request_date = date
    url ="http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=%s" % (api_key, request_data)
    # 위의 url 변수를 이용해 데이터를 요청합니다.
    r = urllib.request.urlopen(url)
    # 요청 페이지의 결과 데이터를 파이썬 내부 데이터로 바꿉니다.
    json_raw = r.read()
    
    json_utf8 = json_raw.decode("utf-8")
    
    json_complete = json.loads(json_utf8)
    box_result = pd.json_normalize(json_complete['boxOfficeResult']['dailyBoxOfficeList'])
    box_result['date'] = request_date
    merged_data = pd.concat([merged_data, box_result])
merged_data
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd                      movieNm  \
# 0    1    1         0           NEW  20194376                      탑건: 매버릭
# 1    2    2        -1           OLD  20224882  마녀(魔女) Part2. The Other One
# 2    3    3        -1           OLD  20204548                       범죄도시 2
# 3    4    4        -1           OLD  20206257                          브로커
# 4    5    5        -1           OLD  20223839                     버즈 라이트이어
# 2  2022-05-18   577713370       15.9  -158550060       -21.5  120660923940
# 3  2022-06-08    96967760        2.7  -120719520       -55.5   11616358360
# 4  2022-06-15    34719200        1.0   -99957740       -74.2    2493961690
# 5  2022-06-01    21223800        0.6   -76011160       -78.2   28777337910
# 6  2022-06-22    13283560        0.4    13283560         100      33442560
# 7  2022-04-27     5090000        0.1     3590000       239.3    3912819280
# 8  2022-03-23     5000000        0.1     2500000         100    3776252970
# 9  2022-04-20     5000000        0.1     2500000         100    1006394850
#
#   audiCnt audiInten audiChange   audiAcc scrnCnt showCnt      date
# 0  188312    188312        100    253016    1975    9158  20220620
# 1   82691    -25491      -23.6   1769461     976    3502  20220620
# 2   57874    -15988      -21.6  11671470     774    2531  20220620
# 3    9992    -12366      -55.3   1160649     449     674  20220620
# 4    3952     -8455      -68.1    233278     287     375  20220620
# 5    2271     -7685      -77.2   2788530     117     141  20220620
# 6    1586      1586        100      3937     122     190  20220620
# 7    1015       715      238.3    409303       3       4  20220620
# 8    1000       500        100    396788       4       5  20220620
# 9    1000       500        100    109848       4       5  20220620
# 0  188312    188312        100    253016    1975    9158  20220621
# 1   82691    -25491      -23.6   1769461     976    3502  20220621
# 2   57874    -15988      -21.6  11671470     774    2531  20220621
# 3    9992    -12366      -55.3   1160649     449     674  20220621
# 4    3952     -8455      -68.1    233278     287     375  20220621
# 5    2271     -7685      -77.2   2788530     117     141  20220621
# 6    1586      1586        100      3937     122     190  20220621
# 7    1015       715      238.3    409303       3       4  20220621
# 8    1000       500        100    396788       4       5  20220621
# 9    1000       500        100    109848       4       5  20220621
# 0  188312    188312        100    253016    1975    9158  20220622
# 1   82691    -25491      -23.6   1769461     976    3502  20220622
# 2   57874    -15988      -21.6  11671470     774    2531  20220622
# 3    9992    -12366      -55.3   1160649     449     674  20220622
# 4    3952     -8455      -68.1    233278     287     375  20220622
# 5    2271     -7685      -77.2   2788530     117     141  20220622
# 6    1586      1586        100      3937     122     190  20220622
# 7    1015       715      238.3    409303       3       4  20220622
# 8    1000       500        100    396788       4       5  20220622
# 9    1000       500        100    109848       4       5  20220622

# %%
# 날짜는 시작날짜와 + 며칠 을 처리할지 결정할 수 있습니다.
# 1년치 데이터를 얻은 다음 to_csv나 to_excel로 저장해주세요.
start_datetime = datetime.datetime(2021, 8, 8) # 년 월 일 순으로 넣어줍니다.

# 반복문과 append를 이용해서 1년치 데이터를 요청해서 합쳐보세요.
# target_date 컬럼에 조회 날짜를 추가해주세요.
# 빈 데이터프레임을 하나 생성해놓고(pd.DataFrame())
merged_data = pd.DataFrame()
for idx in range(365):
    # 날짜를 문자로 변경
    target_date = start_datetime.strftime('%Y%m%d')
    
    api_key = "cf987f1dd58a13d0f7e751c8e0ed1043" # 발급받은 키만 복붙하세요
    request_date = target_date # 조회날짜를  xxxxyydd 20220623 형식으로 넣어주세요
    url = "http://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=%s&targetDt=%s" % (api_key, request_date)
    # 위의 url 변수를 이용해 데이터를 요청합니다.
    r = urllib.request.urlopen(url)

    # 요청 페이지의 결과 데이터를 파이썬 내부 데이터로 바꿉니다.
    json_raw = r.read()
    
    json_utf8 = json_raw.decode("utf-8")
    # json.loads(딕셔너리 형태의 문자열 자료)
    # 딕셔너리 형태로 적힌 문자열 자료를 딕셔너리형으로 변환
    json_complete = json.loads(json_utf8)
    box_result = pd.json_normalize(json_complete['boxOfficeResult']['dailyBoxOfficeList'])
    # box_result에 날짜 컬럼 추가해 날짜 정보 넣기
    box_result['date'] = request_date
    merged_data = pd.concat([merged_data, box_result])
    # 해당 날짜 데이터를 가져와 통합한 뒤에는 날짜를 하루 더해주기
    start_datetime = start_datetime + datetime.timedelta(days=1)
    print("%s일차 자료 수집 완료" % idx)
    # 너무 자주 크롤링시 블록먹을 가능성이 있음.
    time.sleep(1)
    
merged_data
# Out:
# 0일차 자료 수집 완료
# 1일차 자료 수집 완료
# 2일차 자료 수집 완료
# 3일차 자료 수집 완료
# 4일차 자료 수집 완료
# 5일차 자료 수집 완료
# 6일차 자료 수집 완료
# 7일차 자료 수집 완료
# 8일차 자료 수집 완료
# 9일차 자료 수집 완료
# 10일차 자료 수집 완료
# 11일차 자료 수집 완료
# 12일차 자료 수집 완료
# 13일차 자료 수집 완료
# 14일차 자료 수집 완료
# 15일차 자료 수집 완료
# 16일차 자료 수집 완료
# 17일차 자료 수집 완료
# 18일차 자료 수집 완료
# 19일차 자료 수집 완료
# 20일차 자료 수집 완료
# 21일차 자료 수집 완료
# 22일차 자료 수집 완료
# 23일차 자료 수집 완료
# 24일차 자료 수집 완료
# 25일차 자료 수집 완료
# 26일차 자료 수집 완료
# 27일차 자료 수집 완료
# 28일차 자료 수집 완료
# 29일차 자료 수집 완료
# 30일차 자료 수집 완료
# 31일차 자료 수집 완료
# 32일차 자료 수집 완료
# 33일차 자료 수집 완료
# 34일차 자료 수집 완료
# 35일차 자료 수집 완료
# 36일차 자료 수집 완료
# 37일차 자료 수집 완료
# 38일차 자료 수집 완료
# 39일차 자료 수집 완료
# 40일차 자료 수집 완료
# 41일차 자료 수집 완료
# 42일차 자료 수집 완료
# 43일차 자료 수집 완료
# 44일차 자료 수집 완료
# 45일차 자료 수집 완료
# 46일차 자료 수집 완료
# 47일차 자료 수집 완료
# 48일차 자료 수집 완료
# 49일차 자료 수집 완료
# 50일차 자료 수집 완료
# 51일차 자료 수집 완료
# 52일차 자료 수집 완료
# 53일차 자료 수집 완료
# 54일차 자료 수집 완료
# 55일차 자료 수집 완료
# 56일차 자료 수집 완료
# 57일차 자료 수집 완료
# 58일차 자료 수집 완료
# 59일차 자료 수집 완료
# 60일차 자료 수집 완료
# 61일차 자료 수집 완료
# 62일차 자료 수집 완료
# 63일차 자료 수집 완료
# 64일차 자료 수집 완료
# 65일차 자료 수집 완료
# 66일차 자료 수집 완료
# 67일차 자료 수집 완료
# 68일차 자료 수집 완료
# 69일차 자료 수집 완료
# 70일차 자료 수집 완료
# 71일차 자료 수집 완료
# 72일차 자료 수집 완료
# 73일차 자료 수집 완료
# 74일차 자료 수집 완료
# 75일차 자료 수집 완료
# 76일차 자료 수집 완료
# 77일차 자료 수집 완료
# 78일차 자료 수집 완료
# 79일차 자료 수집 완료
# 80일차 자료 수집 완료
# 81일차 자료 수집 완료
# 82일차 자료 수집 완료
# 83일차 자료 수집 완료
# 84일차 자료 수집 완료
# 85일차 자료 수집 완료
# 86일차 자료 수집 완료
# 87일차 자료 수집 완료
# 88일차 자료 수집 완료
# 89일차 자료 수집 완료
# 90일차 자료 수집 완료
# 91일차 자료 수집 완료
# 92일차 자료 수집 완료
# 93일차 자료 수집 완료
# 94일차 자료 수집 완료
# 95일차 자료 수집 완료
# 96일차 자료 수집 완료
# 97일차 자료 수집 완료
# 98일차 자료 수집 완료
# 99일차 자료 수집 완료
# 100일차 자료 수집 완료
# 101일차 자료 수집 완료
# 102일차 자료 수집 완료
# 103일차 자료 수집 완료
# 104일차 자료 수집 완료
# 105일차 자료 수집 완료
# 106일차 자료 수집 완료
# 107일차 자료 수집 완료
# 108일차 자료 수집 완료
# 109일차 자료 수집 완료
# 110일차 자료 수집 완료
# 111일차 자료 수집 완료
# 112일차 자료 수집 완료
# 113일차 자료 수집 완료
# 114일차 자료 수집 완료
# 115일차 자료 수집 완료
# 116일차 자료 수집 완료
# 117일차 자료 수집 완료
# 118일차 자료 수집 완료
# 119일차 자료 수집 완료
# 120일차 자료 수집 완료
# 121일차 자료 수집 완료
# 122일차 자료 수집 완료
# 123일차 자료 수집 완료
# 124일차 자료 수집 완료
# 125일차 자료 수집 완료
# 126일차 자료 수집 완료
# 127일차 자료 수집 완료
# 128일차 자료 수집 완료
# 129일차 자료 수집 완료
# 130일차 자료 수집 완료
# 131일차 자료 수집 완료
# 132일차 자료 수집 완료
# 133일차 자료 수집 완료
# 134일차 자료 수집 완료
# 135일차 자료 수집 완료
# 136일차 자료 수집 완료
# 137일차 자료 수집 완료
# 138일차 자료 수집 완료
# 139일차 자료 수집 완료
# 140일차 자료 수집 완료
# 141일차 자료 수집 완료
# 142일차 자료 수집 완료
# 143일차 자료 수집 완료
# 144일차 자료 수집 완료
# 145일차 자료 수집 완료
# 146일차 자료 수집 완료
# 147일차 자료 수집 완료
# 148일차 자료 수집 완료
# 149일차 자료 수집 완료
# 150일차 자료 수집 완료
# 151일차 자료 수집 완료
# 152일차 자료 수집 완료
# 153일차 자료 수집 완료
# 154일차 자료 수집 완료
# 155일차 자료 수집 완료
# 156일차 자료 수집 완료
# 157일차 자료 수집 완료
# 158일차 자료 수집 완료
# 159일차 자료 수집 완료
# 160일차 자료 수집 완료
# 161일차 자료 수집 완료
# 162일차 자료 수집 완료
# 163일차 자료 수집 완료
# 164일차 자료 수집 완료
# 165일차 자료 수집 완료
# 166일차 자료 수집 완료
# 167일차 자료 수집 완료
# 168일차 자료 수집 완료
# 169일차 자료 수집 완료
# 170일차 자료 수집 완료
# 171일차 자료 수집 완료
# 172일차 자료 수집 완료
# 173일차 자료 수집 완료
# 174일차 자료 수집 완료
# 175일차 자료 수집 완료
# 176일차 자료 수집 완료
# 177일차 자료 수집 완료
# 178일차 자료 수집 완료
# 179일차 자료 수집 완료
# 180일차 자료 수집 완료
# 181일차 자료 수집 완료
# 182일차 자료 수집 완료
# 183일차 자료 수집 완료
# 184일차 자료 수집 완료
# 185일차 자료 수집 완료
# 186일차 자료 수집 완료
# 187일차 자료 수집 완료
# 188일차 자료 수집 완료
# 189일차 자료 수집 완료
# 190일차 자료 수집 완료
# 191일차 자료 수집 완료
# 192일차 자료 수집 완료
# 193일차 자료 수집 완료
# 194일차 자료 수집 완료
# 195일차 자료 수집 완료
# 196일차 자료 수집 완료
# 197일차 자료 수집 완료
# 198일차 자료 수집 완료
# 199일차 자료 수집 완료
# 200일차 자료 수집 완료
# 201일차 자료 수집 완료
# 202일차 자료 수집 완료
# 203일차 자료 수집 완료
# 204일차 자료 수집 완료
# 205일차 자료 수집 완료
# 206일차 자료 수집 완료
# 207일차 자료 수집 완료
# 208일차 자료 수집 완료
# 209일차 자료 수집 완료
# 210일차 자료 수집 완료
# 211일차 자료 수집 완료
# 212일차 자료 수집 완료
# 213일차 자료 수집 완료
# 214일차 자료 수집 완료
# 215일차 자료 수집 완료
# 216일차 자료 수집 완료
# 217일차 자료 수집 완료
# 218일차 자료 수집 완료
# 219일차 자료 수집 완료
# 220일차 자료 수집 완료
# 221일차 자료 수집 완료
# 222일차 자료 수집 완료
# 223일차 자료 수집 완료
# 224일차 자료 수집 완료
# 225일차 자료 수집 완료
# 226일차 자료 수집 완료
# 227일차 자료 수집 완료
# 228일차 자료 수집 완료
# 229일차 자료 수집 완료
# 230일차 자료 수집 완료
# 231일차 자료 수집 완료
# 232일차 자료 수집 완료
# 233일차 자료 수집 완료
# 234일차 자료 수집 완료
# 235일차 자료 수집 완료
# 236일차 자료 수집 완료
# 237일차 자료 수집 완료
# 238일차 자료 수집 완료
# 239일차 자료 수집 완료
# 240일차 자료 수집 완료
# 241일차 자료 수집 완료
# 242일차 자료 수집 완료
# 243일차 자료 수집 완료
# 244일차 자료 수집 완료
# 245일차 자료 수집 완료
# 246일차 자료 수집 완료
# 247일차 자료 수집 완료
# 248일차 자료 수집 완료
# 249일차 자료 수집 완료
# 250일차 자료 수집 완료
# 251일차 자료 수집 완료
# 252일차 자료 수집 완료
# 253일차 자료 수집 완료
# 254일차 자료 수집 완료
# 255일차 자료 수집 완료
# 256일차 자료 수집 완료
# 257일차 자료 수집 완료
# 258일차 자료 수집 완료
# 259일차 자료 수집 완료
# 260일차 자료 수집 완료
# 261일차 자료 수집 완료
# 262일차 자료 수집 완료
# 263일차 자료 수집 완료
# 264일차 자료 수집 완료
# 265일차 자료 수집 완료
# 266일차 자료 수집 완료
# 267일차 자료 수집 완료
# 268일차 자료 수집 완료
# 269일차 자료 수집 완료
# 270일차 자료 수집 완료
# 271일차 자료 수집 완료
# 272일차 자료 수집 완료
# 273일차 자료 수집 완료
# 274일차 자료 수집 완료
# 275일차 자료 수집 완료
# 276일차 자료 수집 완료
# 277일차 자료 수집 완료
# 278일차 자료 수집 완료
# 279일차 자료 수집 완료
# 280일차 자료 수집 완료
# 281일차 자료 수집 완료
# 282일차 자료 수집 완료
# 283일차 자료 수집 완료
# 284일차 자료 수집 완료
# 285일차 자료 수집 완료
# 286일차 자료 수집 완료
# 287일차 자료 수집 완료
# 288일차 자료 수집 완료
# 289일차 자료 수집 완료
# 290일차 자료 수집 완료
# 291일차 자료 수집 완료
# 292일차 자료 수집 완료
# 293일차 자료 수집 완료
# 294일차 자료 수집 완료
# 295일차 자료 수집 완료
# 296일차 자료 수집 완료
# 297일차 자료 수집 완료
# 298일차 자료 수집 완료
# 299일차 자료 수집 완료
# 300일차 자료 수집 완료
# 301일차 자료 수집 완료
# 302일차 자료 수집 완료
# 303일차 자료 수집 완료
# 304일차 자료 수집 완료
# 305일차 자료 수집 완료
# 306일차 자료 수집 완료
# 307일차 자료 수집 완료
# 308일차 자료 수집 완료
# 309일차 자료 수집 완료
# 310일차 자료 수집 완료
# 311일차 자료 수집 완료
# 312일차 자료 수집 완료
# 313일차 자료 수집 완료
# 314일차 자료 수집 완료
# 315일차 자료 수집 완료
# 316일차 자료 수집 완료
# 317일차 자료 수집 완료
# 318일차 자료 수집 완료
# 319일차 자료 수집 완료
# 320일차 자료 수집 완료
# 321일차 자료 수집 완료
# 322일차 자료 수집 완료
# 323일차 자료 수집 완료
# 324일차 자료 수집 완료
# 325일차 자료 수집 완료
# 326일차 자료 수집 완료
# 327일차 자료 수집 완료
# 328일차 자료 수집 완료
# 329일차 자료 수집 완료
# 330일차 자료 수집 완료
# 331일차 자료 수집 완료
# 332일차 자료 수집 완료
# 333일차 자료 수집 완료
# 334일차 자료 수집 완료
# 335일차 자료 수집 완료
# 336일차 자료 수집 완료
# 337일차 자료 수집 완료
# 338일차 자료 수집 완료
# 339일차 자료 수집 완료
# 340일차 자료 수집 완료
# 341일차 자료 수집 완료
# 342일차 자료 수집 완료
# 343일차 자료 수집 완료
# 344일차 자료 수집 완료
# 345일차 자료 수집 완료
# 346일차 자료 수집 완료
# 347일차 자료 수집 완료
# 348일차 자료 수집 완료
# 349일차 자료 수집 완료
# 350일차 자료 수집 완료
# 351일차 자료 수집 완료
# 352일차 자료 수집 완료
# 353일차 자료 수집 완료
# 354일차 자료 수집 완료
# 355일차 자료 수집 완료
# 356일차 자료 수집 완료
# 357일차 자료 수집 완료
# 358일차 자료 수집 완료
# 359일차 자료 수집 완료
# 360일차 자료 수집 완료
# 361일차 자료 수집 완료
# 362일차 자료 수집 완료
# 363일차 자료 수집 완료
# 364일차 자료 수집 완료
#    rnum rank rankInten rankOldAndNew   movieCd  \
# 0     1    1         0           OLD  20204117
# 1     2    2         0           OLD  20217845
# 2     3    3         0           OLD  20218391
# 3     4    4         0           OLD  20191951
# 4     5    5         0           OLD  20218875
# ..  ...  ...       ...           ...       ...
# 5     6    6         1           OLD  20209654
# 6     7    7        -1           OLD  20208446
# 7     8    8         0           OLD  20226107
# 8     9    9         0           OLD  20225237
# 9    10   10         0           OLD  20211792
#
#                             movieNm      openDt    salesAmt salesShare  \
# 0                              모가디슈  2021-07-28  2000829380       56.5
# 1                       더 수어사이드 스쿼드  2021-08-04   676797240       19.1
# 2                          보스 베이비 2  2021-07-21   284206020        8.0
# 3                            블랙 위도우  2021-07-07   194489780        5.5
# 4                 극장판 도라에몽: 진구의 신공룡  2021-08-05    88917620        2.5
# ..                              ...         ...         ...        ...
# 5                            헤어질 결심  2022-06-29   169174033        1.7
# 6                           외계+인 1부  2022-07-20   123965118        1.3
# 7   극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    77727199        0.8
# 8                   명탐정 코난: 할로윈의 신부  2022-07-13    44635198        0.5
# 9                                헌트  2022-08-10    29793598        0.3
#
#     salesInten salesChange     salesAcc audiCnt audiInten audiChange  audiAcc  \
# 0     38859180           2  16579074530  196672      4041        2.1  1712375
# 1   -127499190       -15.9   2942253950   63095    -12197      -16.2   281377
# 2      1506480         0.5   7511398580   30046       108        0.4   836805
# 3    -28197330       -12.7  29457331370   18740     -2673      -12.5  2908679
# 4     -4415810        -4.7    337195080    9837      -612       -5.9    38669
# ..         ...         ...          ...     ...       ...        ...      ...
# 5    -32677140       -16.2  18385204948   15203     -2798      -15.5  1775050
# 6    -98324419       -44.2  15629862451   11690     -7177        -38  1496935
# 7      2170399         2.9    346253298    7903       248        3.2    36417
# 8       623298         1.4   4598589872    4122        13        0.3   442570
# 9     -2295602        -7.2    165546798    2377      -166       -6.5    16573
#
#    scrnCnt showCnt      date
# 0     1639    6757  20210808
# 1     1033    3306  20210808
# 2      777    1654  20210808
# 3      540     924  20210808
# 4      502     781  20210808
# ..     ...     ...       ...
# 5      266     426  20220807
# 6      374     499  20220807
# 7      357     466  20220807
# 8       91     115  20220807
# 9       12      13  20220807
#
# [3650 rows x 19 columns]

# %%
merged_data
# Out:
#    rnum rank rankInten rankOldAndNew   movieCd  \
# 0     1    1         0           OLD  20204117
# 1     2    2         0           OLD  20217845
# 2     3    3         0           OLD  20218391
# 3     4    4         0           OLD  20191951
# 4     5    5         0           OLD  20218875
# ..  ...  ...       ...           ...       ...
# 5     6    6         1           OLD  20209654
# 6     7    7        -1           OLD  20208446
# 7     8    8         0           OLD  20226107
# 8     9    9         0           OLD  20225237
# 9    10   10         0           OLD  20211792
#
#                             movieNm      openDt    salesAmt salesShare  \
# 0                              모가디슈  2021-07-28  2000829380       56.5
# 1                       더 수어사이드 스쿼드  2021-08-04   676797240       19.1
# 2                          보스 베이비 2  2021-07-21   284206020        8.0
# 3                            블랙 위도우  2021-07-07   194489780        5.5
# 4                 극장판 도라에몽: 진구의 신공룡  2021-08-05    88917620        2.5
# ..                              ...         ...         ...        ...
# 5                            헤어질 결심  2022-06-29   169174033        1.7
# 6                           외계+인 1부  2022-07-20   123965118        1.3
# 7   극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    77727199        0.8
# 8                   명탐정 코난: 할로윈의 신부  2022-07-13    44635198        0.5
# 9                                헌트  2022-08-10    29793598        0.3
#
#     salesInten salesChange     salesAcc audiCnt audiInten audiChange  audiAcc  \
# 0     38859180           2  16579074530  196672      4041        2.1  1712375
# 1   -127499190       -15.9   2942253950   63095    -12197      -16.2   281377
# 2      1506480         0.5   7511398580   30046       108        0.4   836805
# 3    -28197330       -12.7  29457331370   18740     -2673      -12.5  2908679
# 4     -4415810        -4.7    337195080    9837      -612       -5.9    38669
# ..         ...         ...          ...     ...       ...        ...      ...
# 5    -32677140       -16.2  18385204948   15203     -2798      -15.5  1775050
# 6    -98324419       -44.2  15629862451   11690     -7177        -38  1496935
# 7      2170399         2.9    346253298    7903       248        3.2    36417
# 8       623298         1.4   4598589872    4122        13        0.3   442570
# 9     -2295602        -7.2    165546798    2377      -166       -6.5    16573
#
#    scrnCnt showCnt      date
# 0     1639    6757  20210808
# 1     1033    3306  20210808
# 2      777    1654  20210808
# 3      540     924  20210808
# 4      502     781  20210808
# ..     ...     ...       ...
# 5      266     426  20220807
# 6      374     499  20220807
# 7      357     466  20220807
# 8       91     115  20220807
# 9       12      13  20220807
#
# [3650 rows x 19 columns]

# %%
# 스크린당 평균 관객이 제일 많았던 영화를 뽑아주세요.
# 관객 총합 / 스크린 총합 = 스크린당 관객이 나옵니다.
# 컬럼 타입이 object이므로, 집계함수를 쓸 수 있도록 int로 전체 자료형을 바꿔줘야 합니다.
# 현재 수치데이터도 전부.문자로 간주되고 있기 때문에 int로 자료형을 바꿔서 계산해야합니다.
merged_data['audiCnt'] = merged_data['audiCnt'].astype(int)
merged_data['scrnCnt'] = merged_data['scrnCnt'].astype(int)

# %%
audi_scrn_sum = merged_data.pivot_table(index='movieNm', values=['audiCnt', 'scrnCnt'], aggfunc='sum').sort_values(by='audiCnt', ascending=False)

# %%
# 관객 총합 / 스크린 총합 = 스크린당 관객이 나옵니다
# 컬럼명은 audiPerScrn
audi_scrn_sum['audiPerScrn'] = audi_scrn_sum['audiCnt'] / audi_scrn_sum['scrnCnt']

# %%
audi_scrn_sum[audi_scrn_sum['scrnCnt'] >= 100].sort_values(by='audiPerScrn', ascending=False).head(10)
# Out:
#                               audiCnt  scrnCnt  audiPerScrn
# movieNm
# 한산: 용의 출현                     4597833    22656   202.941075
# 비상선언                          1397965     8489   164.679585
# 범죄도시 2                       12686014    81645   155.380170
# 탑건: 매버릭                       7448596    57863   128.728134
# 닥터 스트레인지: 대혼돈의 멀티버스           5880700    48993   120.031433
# 쥬라기 월드: 도미니언                  2832531    24893   113.788254
# 마녀(魔女) Part2. The Other One   2795796    27322   102.327648
# 토르: 러브 앤 썬더                   2711863    26516   102.272703
# 미니언즈2                         1971484    19463   101.293942
# 스파이더맨: 노 웨이 홈                 7541536    90668    83.177483

# %%
# 스크린 개수가 50개 이상인 영화중 스크린당 관객수가 평균이상인 영화만 나열해주세요
audi_scrn_sum[audi_scrn_sum['scrnCnt'] >= 50]['audiPerScrn'].mean()
# Out:
# 26.82794093573036

# %%
final_data = audi_scrn_sum[(audi_scrn_sum['scrnCnt'] >= 50) & (audi_scrn_sum['audiPerScrn']>=26.8)].head(50)

# %%
# csv로 export하기
final_data.to_csv('평균이상영화.csv', encoding="utf-8")

# %%
# excel로 export 하기
final_data.to_excel('평균이상영화.xlsx', encoding="utf-8")

# %% [markdown]
# ## 오라클 연동
#
# 위와 같은데 3번에서
# - pip install cx_Oracle
# - 을 대신 입력해서 설치하면 됩니다.

# %%
# pymysql 실행을 해야 DB와 연결할 수 있습니다.
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [89], in <cell line: 3>()
#       1 # pymysql 실행을 해야 DB와 연결할 수 있습니다.
#       2 import pymysql
# ----> 3 import pyOracle
#
# ModuleNotFoundError: No module named 'pyOracle'

# %%
# MySQL 연결에 필요한 정보를 입력합니다.
con = pymysql.connect(host='localhost', user='root', password='mysql', db='pyprac2', charset='utf8',
                     cursorclass=pymysql.cursors.DictCursor) # 컬럼명까지 받아올지 여부 cursorclass=pymysql.cursors.DictCursor을 붙여야 dataFrame이 제대로나옴 아니면 리스트만나옴

# %%
# SQL 구문을 받아주는 cursor 객체를 사용합니다.
cur = con.cursor()

# %%
# SQL 구문은 문자로 cur.execute()를 실행해서 수행시킵니다.
cur.execute("SELECT * FROM test_tbl2")
# Out:
# 7

# %%
# execute가 실행되면, cur가 데이터를 저장하고 있는데 이걸 파이썬 형식으로 빼야합니다.
mysql_data = cur.fetchall()

# %%
mysql_data
# Out:
# [{'tno': 1, 'tname': 'a'},
#  {'tno': 2, 'tname': 'b'},
#  {'tno': 3, 'tname': 'd'},
#  {'tno': 4, 'tname': 'd'},
#  {'tno': 5, 'tname': 'e'},
#  {'tno': 6, 'tname': 'f'},
#  {'tno': 7, 'tname': 'g'}]

# %%
# 데이터프레임 형태로 변환
pd.DataFrame(mysql_data)
# Out:
#    tno tname
# 0    1     a
# 1    2     b
# 2    3     d
# 3    4     d
# 4    5     e
# 5    6     f
# 6    7     g

# %%
# 여러분들이 data 'g'를 넣어보세요.
cur.execute("INSERT INTO test_tbl2 (tname) VALUES ('g')")
# Out:
# 1

# %%
# 커서가 아닌 커넥션에 commit을 주는것에 주의해주세요.
con.commit()

# %%
cur.execute("SELECT * FROM test_tbl2")
# Out:
# 8

# %%
mysql_data = cur.fetchall()

# %%
pd.DataFrame(mysql_data)
# Out:
#    tno tname
# 0    1     a
# 1    2     b
# 2    3     d
# 3    4     d
# 4    5     e
# 5    6     f
# 6    7     g
# 7    8     g

# %%
# movie_tbl 데이터를 다 삭제하는 쿼리문을 날려주세요.
cur.execute("DELETE FROM movie_tbl")
con.commit()

# %%
# 로우개수
len(merged_data) # 3650번 반복해야 DB에 insert가 된다는걸 알 수 있음.
# iloc[], .loc[] 를 이용하면 특정 로우자료를 조회할 수 있고, 거기서 ['컬럼명']을 집어넣으면
# 특정 로우의 특정 컬럽값을 조회할 수 있습니다.
merged_data.iloc[4]['movieNm']
# Out:
# '극장판 도라에몽: 진구의 신공룡'

# %%
# 과제. MySQL 이나 Oracle SQL에 현재 보고 있는 db_insert데이터를
# 테이블 생성 및 반복문을 이용해서 다 DB에 넣어주시면 됩니다.
# 반복문을 이용해서 merged_data의 모든 데이터를 MySQL에 집어넣어주세요.
# 집어넣을 컬럼은 rnum, movieNm, openDt, audiCnt, showCnt, date

# %%
merged_data['movieNm']
# Out:
# 0                               모가디슈
# 1                        더 수어사이드 스쿼드
# 2                           보스 베이비 2
# 3                             블랙 위도우
# 4                  극장판 도라에몽: 진구의 신공룡
#                   ...
# 5                             헤어질 결심
# 6                            외계+인 1부
# 7    극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021
# 8                    명탐정 코난: 할로윈의 신부
# 9                                 헌트
# Name: movieNm, Length: 3650, dtype: object

# %%
cur.execute("INSERT INTO movie_tbl (movieNm, openDt, audiCnt, showCnt, dataDate) VALUES ('%s', '%s', %s, %s, %s)" % ("테스트", "2022-08-10,", 300, 1, '20220810'))
# Out:
# 1

# %%
con.commit()

# %%
# merged_data변수 내부의 영화 제목만 한 줄 한 줄 콘솔에 찍어보세요.
# len() 을 이용해 데이터프레임의 로우 개수를 구할 수 있습니다.
for i in range(len(merged_data)):
    selected_data = merged_data.iloc[i]
    print(selected_data['movieNm'])
    print(selected_data['openDt'])
    print(selected_data['audiCnt'])
    print(selected_data['showCnt'])
    print(selected_data['date'])
    print("------------------------")
    cur.execute("INSERT INTO movie_tbl (movieNm, openDt, audiCnt, showCnt, dataDate) VALUES ('%s', '%s', %s, %s, %s)" % (selected_data['movieNm'], selected_data['openDt'], selected_data['audiCnt'], selected_data['showCnt'], selected_data['date']))
# Out:
#   Input In [59]
#     cur.execute("INSERT INTO movie_tbl (movieNm, openDt, audiCnt, showCnt, dataDate) VALUES ("%s", '%s', %s, %s, %s)" % (selected_data['movieNm'], selected_data['openDt'], selected_data['audiCnt'], selected_data['showCnt'], selected_data['date']))
#                                                                                                 ^
# SyntaxError: invalid syntax

# %%
# 날짜가 안 들어가는 이유는, 개봉날짜가 빈 칸으로(날짜형식이 아닌) 집계되는 부분이 있어서입니다.
# 따라서 결측치나 이상값을 집계가능한 값으로 돌려놓고(1900-01-01) 다시 insert를 하면 됩니다.
# 반복문으로 인덱스번호, 날짜 형식으로 출력하도록 해서 몇 번 인덱스가 결측치인지 파악해보겠습니다.
for i in range(len(merged_data)):
    print(i, merged_data['movieNm'].iloc[i])
# Out:
# 0 모가디슈
# 1 더 수어사이드 스쿼드
# 2 보스 베이비 2
# 3 블랙 위도우
# 4 극장판 도라에몽: 진구의 신공룡
# 5 정글 크루즈
# 6 방법: 재차의
# 7 블랙핑크 더 무비
# 8 그린 나이트
# 9 랑종
# 10 모가디슈
# 11 더 수어사이드 스쿼드
# 12 보스 베이비 2
# 13 블랙 위도우
# 14 정글 크루즈
# 15 싱크홀
# 16 극장판 도라에몽: 진구의 신공룡
# 17 방법: 재차의
# 18 그린 나이트
# 19 랑종
# 20 모가디슈
# 21 더 수어사이드 스쿼드
# 22 보스 베이비 2
# 23 블랙 위도우
# 24 극장판 도라에몽: 진구의 신공룡
# 25 정글 크루즈
# 26 싱크홀
# 27 방법: 재차의
# 28 그린 나이트
# 29 랑종
# 30 싱크홀
# 31 모가디슈
# 32 프리 가이
# 33 더 수어사이드 스쿼드
# 153 올드
# 154 프리 가이
# 155 퍼피 구조대 더 무비
# 156 더 수어사이드 스쿼드
# 157 블랙 위도우
# 158 보스 베이비 2
# 159 레미니센스
# 160 인질
# 161 싱크홀
# 162 모가디슈
# 163 올드
# 164 프리 가이
# 165 퍼피 구조대 더 무비
# 166 더 수어사이드 스쿼드
# 167 코다
# 168 블랙 위도우
# 169 남색대문
# 170 인질
# 171 싱크홀
# 172 모가디슈
# 173 귀문
# 174 레미니센스
# 175 여름날 우리
# 176 프리 가이
# 177 올드
# 178 퍼피 구조대 더 무비
# 179 더 수어사이드 스쿼드
# 180 인질
# 181 싱크홀
# 182 모가디슈
# 183 귀문
# 184 레미니센스
# 185 여름날 우리
# 186 프리 가이
# 187 올드
# 188 극장판 페이트/그랜드 오더 신성원탁영역 카멜롯 팔라딘; 아가트람
# 189 드림걸즈
# 190 인질
# 191 싱크홀
# 192 모가디슈
# 193 귀문
# 194 레미니센스
# 195 프리 가이
# 196 여름날 우리
# 197 올드
# 198 샹치와 텐 링즈의 전설
# 199 퍼피 구조대 더 무비
# 200 인질
# 201 싱크홀
# 202 모가디슈
# 203 귀문
# 204 프리 가이
# 205 레미니센스
# 206 퍼피 구조대 더 무비
# 207 여름날 우리
# 208 올드
# 209 다이노 마이 프렌드
# 210 인질
# 211 싱크홀
# 212 모가디슈
# 213 귀문
# 214 프리 가이
# 215 퍼피 구조대 더 무비
# 216 레미니센스
# 217 여름날 우리
# 218 올드
# 219 다이노 마이 프렌드
# 220 인질
# 221 모가디슈
# 222 싱크홀
# 223 귀문
# 224 프리 가이
# 225 여름날 우리
# 226 레미니센스
# 227 올드
# 228 퍼피 구조대 더 무비
# 229 드림걸즈
# 230 인질
# 231 모가디슈
# 232 싱크홀
# 233 귀문
# 234 코다
# 235 프리 가이
# 236 여름날 우리
# 237 맨 인 더 다크 2
# 238 상견니
# 239 레미니센스
# 240 샹치와 텐 링즈의 전설
# 241 인질
# 242 모가디슈
# 243 싱크홀
# 244 맨 인 더 다크 2
# 245 코다
# 246 여름날 우리
# 247 귀문
# 248 건파우더 밀크셰이크
# 249 상견니
# 250 샹치와 텐 링즈의 전설
# 251 인질
# 252 모가디슈
# 253 싱크홀
# 254 맨 인 더 다크 2
# 255 코다
# 256 귀문
# 257 내일의 기억
# 258 여름날 우리
# 259 최선의 삶
# 260 샹치와 텐 링즈의 전설
# 261 인질
# 262 모가디슈
# 263 싱크홀
# 264 맨 인 더 다크 2
# 265 코다
# 266 귀문
# 267 여름날 우리
# 268 상견니
# 269 최선의 삶
# 270 샹치와 텐 링즈의 전설
# 271 인질
# 272 모가디슈
# 273 싱크홀
# 274 맨 인 더 다크 2
# 275 코다
# 276 퍼피 구조대 더 무비
# 277 귀문
# 278 여름날 우리
# 279 프리 가이
# 280 샹치와 텐 링즈의 전설
# 281 인질
# 282 모가디슈
# 283 싱크홀
# 284 맨 인 더 다크 2
# 285 코다
# 286 퍼피 구조대 더 무비
# 287 귀문
# 288 여름날 우리
# 289 프리 가이
# 290 샹치와 텐 링즈의 전설
# 291 인질
# 292 모가디슈
# 293 싱크홀
# 294 리스펙트
# 295 맨 인 더 다크 2
# 296 코다
# 297 보이스
# 298 기적
# 299 귀문
# 300 샹치와 텐 링즈의 전설
# 301 인질
# 302 모가디슈
# 303 싱크홀
# 304 맨 인 더 다크 2
# 305 보이스
# 306 코다
# 307 최선의 삶
# 308 여름날 우리
# 309 프리 가이
# 310 샹치와 텐 링즈의 전설
# 311 인질
# 312 모가디슈
# 313 건파우더 밀크셰이크
# 314 싱크홀
# 315 맨 인 더 다크 2
# 316 보이스
# 317 코다
# 318 파이프라인
# 319 리스펙트
# 320 샹치와 텐 링즈의 전설
# 321 모가디슈
# 322 인질
# 323 너의 이름은.
# 324 싱크홀
# 325 건파우더 밀크셰이크
# 326 날씨의 아이
# 327 좋은 사람
# 328 맨 인 더 다크 2
# 329 잔나비 판타스틱 올드패션드 리턴즈! x 넌센스 Ⅱ
# 330 샹치와 텐 링즈의 전설
# 331 모가디슈
# 332 인질
# 333 싱크홀
# 334 너의 이름은.
# 335 건파우더 밀크셰이크
# 336 맨 인 더 다크 2
# 337 코다
# 338 날씨의 아이
# 339 좋은 사람
# 340 샹치와 텐 링즈의 전설
# 341 모가디슈
# 342 인질
# 343 싱크홀
# 344 너의 이름은.
# 345 맨 인 더 다크 2
# 346 건파우더 밀크셰이크
# 347 보이스
# 348 기적
# 349 날씨의 아이
# 350 샹치와 텐 링즈의 전설
# 351 모가디슈
# 352 인질
# 353 싱크홀
# 354 너의 이름은.
# 355 맨 인 더 다크 2
# 356 보이스
# 357 건파우더 밀크셰이크
# 358 날씨의 아이
# 359 기적
# 360 샹치와 텐 링즈의 전설
# 361 인질
# 362 모가디슈
# 363 리스펙트
# 364 싱크홀
# 365 너의 이름은.
# 366 맨 인 더 다크 2
# 367 건파우더 밀크셰이크
# 368 코다
# 369 잔나비 판타스틱 올드패션드 리턴즈! x 넌센스 Ⅱ
# 370 샹치와 텐 링즈의 전설
# 371 인질
# 372 모가디슈
# 373 싱크홀
# 374 건파우더 밀크셰이크
# 375 너의 이름은.
# 376 맨 인 더 다크 2
# 377 코다
# 378 날씨의 아이
# 379 리스펙트
# 380 보이스
# 381 기적
# 382 해리포터와 마법사의 돌
# 383 샹치와 텐 링즈의 전설
# 384 극장판 포켓몬스터: 정글의 아이, 코코
# 385 모가디슈
# 386 말리그넌트
# 387 인질
# 388 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 389 콰이어트 플레이스 2
# 390 보이스
# 391 기적
# 392 샹치와 텐 링즈의 전설
# 393 해리포터와 마법사의 돌
# 394 인질
# 395 극장판 포켓몬스터: 정글의 아이, 코코
# 396 모가디슈
# 397 말리그넌트
# 398 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 399 너의 이름은.
# 400 보이스
# 401 기적
# 402 샹치와 텐 링즈의 전설
# 403 모가디슈
# 404 인질
# 405 말리그넌트
# 406 극장판 포켓몬스터: 정글의 아이, 코코
# 407 해리포터와 마법사의 돌
# 408 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 409 너의 이름은.
# 410 보이스
# 411 기적
# 412 샹치와 텐 링즈의 전설
# 413 극장판 포켓몬스터: 정글의 아이, 코코
# 414 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 415 모가디슈
# 416 인질
# 417 해리포터와 마법사의 돌
# 418 말리그넌트
# 419 너의 이름은.
# 420 보이스
# 421 샹치와 텐 링즈의 전설
# 422 기적
# 423 극장판 포켓몬스터: 정글의 아이, 코코
# 424 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 425 모가디슈
# 426 인질
# 427 해리포터와 마법사의 돌
# 428 말리그넌트
# 429 너의 이름은.
# 430 보이스
# 431 샹치와 텐 링즈의 전설
# 432 기적
# 433 모가디슈
# 434 극장판 포켓몬스터: 정글의 아이, 코코
# 435 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 436 인질
# 437 해리포터와 마법사의 돌
# 438 말리그넌트
# 439 너의 이름은.
# 440 보이스
# 441 기적
# 442 샹치와 텐 링즈의 전설
# 443 모가디슈
# 444 극장판 포켓몬스터: 정글의 아이, 코코
# 445 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 446 인질
# 447 해리포터와 마법사의 돌
# 448 말리그넌트
# 449 싱크홀
# 450 보이스
# 451 기적
# 452 샹치와 텐 링즈의 전설
# 453 모가디슈
# 454 극장판 포켓몬스터: 정글의 아이, 코코
# 455 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 456 캔디맨
# 457 인질
# 458 해리포터와 마법사의 돌
# 459 말리그넌트
# 460 보이스
# 461 기적
# 462 샹치와 텐 링즈의 전설
# 463 모가디슈
# 464 캔디맨
# 465 극장판 포켓몬스터: 정글의 아이, 코코
# 466 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 467 인질
# 468 해리포터와 마법사의 돌
# 469 말리그넌트
# 470 보이스
# 471 기적
# 472 샹치와 텐 링즈의 전설
# 473 모가디슈
# 474 캔디맨
# 475 인질
# 476 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 477 해리포터와 마법사의 돌
# 478 극장판 포켓몬스터: 정글의 아이, 코코
# 479 캐시트럭
# 480 보이스
# 481 기적
# 482 샹치와 텐 링즈의 전설
# 483 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 484 극장판 포켓몬스터: 정글의 아이, 코코
# 485 모가디슈
# 486 캔디맨
# 487 인질
# 488 해리포터와 마법사의 돌
# 489 올드
# 490 보이스
# 491 기적
# 492 샹치와 텐 링즈의 전설
# 493 극장판 포켓몬스터: 정글의 아이, 코코
# 494 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 495 모가디슈
# 496 캔디맨
# 497 인질
# 498 해리포터와 마법사의 돌
# 499 잔나비 판타스틱 올드패션드 리턴즈! x 넌센스 Ⅱ
# 500 보이스
# 501 기적
# 502 샹치와 텐 링즈의 전설
# 503 모가디슈
# 504 캔디맨
# 505 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 506 인질
# 507 극장판 포켓몬스터: 정글의 아이, 코코
# 508 해리포터와 마법사의 돌
# 509 말리그넌트
# 510 보이스
# 511 기적
# 512 샹치와 텐 링즈의 전설
# 513 모가디슈
# 514 스틸워터
# 515 캔디맨
# 516 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 517 인질
# 518 극장판 포켓몬스터: 정글의 아이, 코코
# 519 해리포터와 마법사의 돌
# 520 007 노 타임 투 다이
# 521 보이스
# 522 기적
# 523 샹치와 텐 링즈의 전설
# 524 용과 주근깨 공주
# 525 수색자
# 526 모가디슈
# 527 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 528 인질
# 529 그린 나이트
# 530 007 노 타임 투 다이
# 531 보이스
# 532 기적
# 533 샹치와 텐 링즈의 전설
# 534 모가디슈
# 535 수색자
# 536 용과 주근깨 공주
# 537 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 538 정글 크루즈
# 539 인질
# 540 007 노 타임 투 다이
# 541 보이스
# 542 기적
# 543 샹치와 텐 링즈의 전설
# 544 수색자
# 545 용과 주근깨 공주
# 546 모가디슈
# 547 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 548 레드 아워
# 549 극장판 포켓몬스터: 정글의 아이, 코코
# 550 007 노 타임 투 다이
# 551 보이스
# 552 기적
# 553 샹치와 텐 링즈의 전설
# 554 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 555 용과 주근깨 공주
# 556 극장판 포켓몬스터: 정글의 아이, 코코
# 557 수색자
# 558 모가디슈
# 559 캔디맨
# 560 007 노 타임 투 다이
# 561 보이스
# 562 기적
# 563 샹치와 텐 링즈의 전설
# 564 용과 주근깨 공주
# 565 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 566 극장판 포켓몬스터: 정글의 아이, 코코
# 567 모가디슈
# 568 수색자
# 569 랑종
# 570 007 노 타임 투 다이
# 571 보이스
# 572 기적
# 573 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 574 극장판 포켓몬스터: 정글의 아이, 코코
# 575 용과 주근깨 공주
# 576 샹치와 텐 링즈의 전설
# 577 모가디슈
# 578 수색자
# 579 랑종
# 580 007 노 타임 투 다이
# 581 보이스
# 582 기적
# 583 샹치와 텐 링즈의 전설
# 584 용과 주근깨 공주
# 585 수색자
# 586 모가디슈
# 587 베놈 2: 렛 데어 비 카니지
# 588 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 589 노회찬6411
# 590 007 노 타임 투 다이
# 591 보이스
# 592 기적
# 593 F20
# 594 그래비티
# 595 스틸워터
# 596 화이트데이: 부서진 결계
# 597 샹치와 텐 링즈의 전설
# 598 용과 주근깨 공주
# 599 인질
# 600 007 노 타임 투 다이
# 601 보이스
# 602 기적
# 603 용과 주근깨 공주
# 604 쁘띠 마망
# 605 샹치와 텐 링즈의 전설
# 606 F20
# 607 그래비티
# 608 스틸워터
# 609 화이트데이: 부서진 결계
# 610 007 노 타임 투 다이
# 611 보이스
# 612 기적
# 613 용과 주근깨 공주
# 614 샹치와 텐 링즈의 전설
# 615 F20
# 616 스틸워터
# 617 그래비티
# 618 모가디슈
# 619 화이트데이: 부서진 결계
# 620 007 노 타임 투 다이
# 621 보이스
# 622 기적
# 623 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 624 용과 주근깨 공주
# 625 샹치와 텐 링즈의 전설
# 626 극장판 포켓몬스터: 정글의 아이, 코코
# 627 그래비티
# 628 스틸워터
# 629 모가디슈
# 630 007 노 타임 투 다이
# 631 보이스
# 632 기적
# 633 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 634 샹치와 텐 링즈의 전설
# 635 극장판 포켓몬스터: 정글의 아이, 코코
# 636 용과 주근깨 공주
# 637 모가디슈
# 638 그래비티
# 639 스틸워터
# 640 007 노 타임 투 다이
# 641 보이스
# 642 기적
# 643 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 644 극장판 포켓몬스터: 정글의 아이, 코코
# 645 샹치와 텐 링즈의 전설
# 646 용과 주근깨 공주
# 647 모가디슈
# 648 매직 스쿨: 초보마법사 아우라의 대모험
# 649 스틸워터
# 650 007 노 타임 투 다이
# 651 보이스
# 652 기적
# 653 F20
# 654 노회찬6411
# 655 스틸워터
# 656 모가디슈
# 657 샹치와 텐 링즈의 전설
# 658 용과 주근깨 공주
# 659 여름날 우리
# 660 베놈 2: 렛 데어 비 카니지
# 661 007 노 타임 투 다이
# 662 보이스
# 663 기적
# 664 피어썸
# 665 용과 주근깨 공주
# 666 쁘띠 마망
# 667 스틸워터
# 668 모가디슈
# 669 고양이를 부탁해
# 670 베놈 2: 렛 데어 비 카니지
# 671 007 노 타임 투 다이
# 672 보이스
# 673 노회찬6411
# 674 기적
# 675 십개월의 미래
# 676 용과 주근깨 공주
# 677 타다: 대한민국 스타트업의 초상
# 678 모가디슈
# 679 실: 인연의 시작
# 680 베놈 2: 렛 데어 비 카니지
# 681 007 노 타임 투 다이
# 682 보이스
# 683 기적
# 684 노회찬6411
# 685 십개월의 미래
# 686 용과 주근깨 공주
# 687 타다: 대한민국 스타트업의 초상
# 688 모가디슈
# 689 실: 인연의 시작
# 690 베놈 2: 렛 데어 비 카니지
# 691 007 노 타임 투 다이
# 692 보이스
# 693 기적
# 694 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 695 노회찬6411
# 696 극장판 포켓몬스터: 정글의 아이, 코코
# 697 용과 주근깨 공주
# 698 십개월의 미래
# 699 스페이스 독 3: 트로피컬 어드벤처
# 700 베놈 2: 렛 데어 비 카니지
# 701 007 노 타임 투 다이
# 702 보이스
# 703 기적
# 704 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 705 극장판 포켓몬스터: 정글의 아이, 코코
# 706 노회찬6411
# 707 스페이스 독 3: 트로피컬 어드벤처
# 708 용과 주근깨 공주
# 709 십개월의 미래
# 710 베놈 2: 렛 데어 비 카니지
# 711 007 노 타임 투 다이
# 712 보이스
# 713 F20
# 714 기적
# 715 듄
# 716 노회찬6411
# 717 십개월의 미래
# 718 코다
# 719 스피릿
# 720 베놈 2: 렛 데어 비 카니지
# 721 007 노 타임 투 다이
# 722 보이스
# 723 기적
# 724 듄
# 725 자산어보
# 726 노회찬6411
# 727 십개월의 미래
# 728 용과 주근깨 공주
# 729 모가디슈
# 730 듄
# 731 베놈 2: 렛 데어 비 카니지
# 732 태일이
# 733 라스트 듀얼: 최후의 결투
# 734 007 노 타임 투 다이
# 735 보이스
# 736 기적
# 737 첫눈이 사라졌다
# 738 스피릿
# 739 십개월의 미래
# 740 베놈 2: 렛 데어 비 카니지
# 741 듄
# 742 라스트 듀얼: 최후의 결투
# 743 007 노 타임 투 다이
# 744 보이스
# 745 기적
# 746 노회찬6411
# 747 휴가
# 748 첫눈이 사라졌다
# 749 타다: 대한민국 스타트업의 초상
# 750 베놈 2: 렛 데어 비 카니지
# 751 듄
# 752 라스트 듀얼: 최후의 결투
# 753 007 노 타임 투 다이
# 754 보이스
# 755 기적
# 756 노회찬6411
# 757 동백
# 758 첫눈이 사라졌다
# 759 휴가
# 760 베놈 2: 렛 데어 비 카니지
# 761 듄
# 762 007 노 타임 투 다이
# 763 라스트 듀얼: 최후의 결투
# 764 보이스
# 765 기적
# 766 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 767 극장판 포켓몬스터: 정글의 아이, 코코
# 768 BIAF2021 한국 단편 경쟁 B
# 769 용과 주근깨 공주
# 770 베놈 2: 렛 데어 비 카니지
# 771 듄
# 772 007 노 타임 투 다이
# 773 라스트 듀얼: 최후의 결투
# 774 보이스
# 775 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 776 기적
# 777 극장판 포켓몬스터: 정글의 아이, 코코
# 778 BIAF2021 한국 단편 경쟁 B
# 779 용과 주근깨 공주
# 780 베놈 2: 렛 데어 비 카니지
# 781 듄
# 782 보이스
# 783 007 노 타임 투 다이
# 784 라스트 듀얼: 최후의 결투
# 785 스틸워터
# 786 기적
# 787 노회찬6411
# 788 동백
# 789 그림자꽃
# 790 베놈 2: 렛 데어 비 카니지
# 791 듄
# 792 보이스
# 793 라스트 듀얼: 최후의 결투
# 794 007 노 타임 투 다이
# 795 기적
# 796 BIAF2021 한국 단편 경쟁 B
# 797 한창나이 선녀님
# 798 휴가
# 799 모가디슈
# 800 듄
# 801 베놈 2: 렛 데어 비 카니지
# 802 고장난 론
# 803 아네트
# 804 보이스
# 805 애프터: 관계의 함정
# 806 기적
# 807 라스트 듀얼: 최후의 결투
# 808 007 노 타임 투 다이
# 809 모가디슈
# 810 듄
# 811 베놈 2: 렛 데어 비 카니지
# 812 고장난 론
# 813 아네트
# 814 보이스
# 815 기적
# 816 애프터: 관계의 함정
# 817 007 노 타임 투 다이
# 818 라스트 듀얼: 최후의 결투
# 819 당신은 믿지 않겠지만
# 820 듄
# 821 베놈 2: 렛 데어 비 카니지
# 822 고장난 론
# 823 아네트
# 824 보이스
# 825 기적
# 826 007 노 타임 투 다이
# 827 애프터: 관계의 함정
# 828 라스트 듀얼: 최후의 결투
# 829 모가디슈
# 830 듄
# 831 베놈 2: 렛 데어 비 카니지
# 832 고장난 론
# 833 바다 탐험대 옥토넛 : 육지수호 대작전
# 834 보이스
# 835 007 노 타임 투 다이
# 836 아네트
# 837 라스트 듀얼: 최후의 결투
# 838 애프터: 관계의 함정
# 839 기적
# 840 듄
# 841 베놈 2: 렛 데어 비 카니지
# 842 고장난 론
# 843 바다 탐험대 옥토넛 : 육지수호 대작전
# 844 보이스
# 845 007 노 타임 투 다이
# 846 라스트 듀얼: 최후의 결투
# 847 아네트
# 848 애프터: 관계의 함정
# 849 기적
# 850 듄
# 851 베놈 2: 렛 데어 비 카니지
# 852 고장난 론
# 853 더 하더 데이 폴
# 854 보이스
# 855 아네트
# 856 007 노 타임 투 다이
# 857 라스트 듀얼: 최후의 결투
# 858 기적
# 859 애프터: 관계의 함정
# 860 듄
# 861 베놈 2: 렛 데어 비 카니지
# 862 고장난 론
# 863 보이스
# 864 아네트
# 865 기적
# 866 라스트 듀얼: 최후의 결투
# 867 007 노 타임 투 다이
# 868 애프터: 관계의 함정
# 869 한창나이 선녀님
# 870 이터널스
# 871 듄
# 872 베놈 2: 렛 데어 비 카니지
# 873 고장난 론
# 874 동백
# 875 아네트
# 876 기적
# 877 보이스
# 878 인질
# 879 프리 가이
# 880 이터널스
# 881 듄
# 882 베놈 2: 렛 데어 비 카니지
# 883 세버그
# 884 고장난 론
# 885 장르만 로맨스
# 886 빌리 홀리데이
# 887 기적
# 888 보이스
# 889 아네트
# 890 이터널스
# 891 듄
# 892 베놈 2: 렛 데어 비 카니지
# 893 고장난 론
# 894 세버그
# 895 기적
# 896 동백
# 897 아네트
# 898 빌리 홀리데이
# 899 보이스
# 900 이터널스
# 901 듄
# 902 베놈 2: 렛 데어 비 카니지
# 903 고장난 론
# 904 바다 탐험대 옥토넛 : 육지수호 대작전
# 905 아네트
# 906 세버그
# 907 퍼스트 카우
# 908 기적
# 909 빌리 홀리데이
# 910 이터널스
# 911 듄
# 912 베놈 2: 렛 데어 비 카니지
# 913 고장난 론
# 914 바다 탐험대 옥토넛 : 육지수호 대작전
# 915 아네트
# 916 세버그
# 917 빌리 홀리데이
# 918 퍼스트 카우
# 919 기적
# 920 이터널스
# 921 듄
# 922 베놈 2: 렛 데어 비 카니지
# 923 아네트
# 924 고장난 론
# 925 강릉
# 926 기적
# 927 보이스
# 928 싱크홀
# 929 빌리 홀리데이
# 930 이터널스
# 931 듄
# 932 베놈 2: 렛 데어 비 카니지
# 933 고장난 론
# 934 디어 에반 핸슨
# 935 보이스
# 936 강릉
# 937 기적
# 938 세버그
# 939 아네트
# 940 이터널스
# 941 강릉
# 942 듄
# 943 귀멸의 칼날: 남매의 연
# 944 아담스 패밀리 2
# 945 베놈 2: 렛 데어 비 카니지
# 946 기적
# 947 고장난 론
# 948 그림자꽃
# 949 보이스
# 950 이터널스
# 951 강릉
# 952 듄
# 953 귀멸의 칼날: 남매의 연
# 954 아담스 패밀리 2
# 955 장르만 로맨스
# 956 베놈 2: 렛 데어 비 카니지
# 957 1984 최동원
# 958 태일이
# 959 고장난 론
# 960 이터널스
# 961 강릉
# 962 듄
# 963 아담스 패밀리 2
# 964 귀멸의 칼날: 남매의 연
# 965 베놈 2: 렛 데어 비 카니지
# 966 장르만 로맨스
# 967 틱, 틱... 붐!
# 968 고장난 론
# 969 1984 최동원
# 970 이터널스
# 971 듄
# 972 강릉
# 973 아담스 패밀리 2
# 974 귀멸의 칼날: 남매의 연
# 975 베놈 2: 렛 데어 비 카니지
# 976 고장난 론
# 977 틱, 틱... 붐!
# 978 1984 최동원
# 979 바다 탐험대 옥토넛 : 육지수호 대작전
# 980 이터널스
# 981 강릉
# 982 듄
# 983 아담스 패밀리 2
# 984 귀멸의 칼날: 남매의 연
# 985 베놈 2: 렛 데어 비 카니지
# 986 고장난 론
# 987 틱, 틱... 붐!
# 988 장르만 로맨스
# 989 바다 탐험대 옥토넛 : 육지수호 대작전
# 990 이터널스
# 991 강릉
# 992 듄
# 993 장르만 로맨스
# 994 아담스 패밀리 2
# 995 귀멸의 칼날: 남매의 연
# 996 베놈 2: 렛 데어 비 카니지
# 997 유체이탈자
# 998 디어 에반 핸슨
# 999 틱, 틱... 붐!
# 1000 이터널스
# 1001 강릉
# 1002 듄
# 1003 아담스 패밀리 2
# 1004 귀멸의 칼날: 남매의 연
# 1005 베놈 2: 렛 데어 비 카니지
# 1006 기적
# 1007 동백
# 1008 유체이탈자
# 1009 고장난 론
# 1010 장르만 로맨스
# 1011 이터널스
# 1012 디어 에반 핸슨
# 1013 듄
# 1014 강릉
# 1015 귀멸의 칼날: 나타구모산 편
# 1016 연애 빠진 로맨스
# 1017 귀멸의 칼날: 남매의 연
# 1018 기적
# 1019 아담스 패밀리 2
# 1020 이터널스
# 1021 장르만 로맨스
# 1022 듄
# 1023 디어 에반 핸슨
# 1024 프렌치 디스패치
# 1025 강릉
# 1026 호빗: 뜻밖의 여정
# 1027 뱅드림! 필름 라이브 세컨드 스테이지
# 1028 귀멸의 칼날: 나타구모산 편
# 1029 연애 빠진 로맨스
# 1030 장르만 로맨스
# 1031 이터널스
# 1032 듄
# 1033 디어 에반 핸슨
# 1034 강릉
# 1035 프렌치 디스패치
# 1036 귀멸의 칼날: 나타구모산 편
# 1037 뱅드림! 필름 라이브 세컨드 스테이지
# 1038 호빗: 뜻밖의 여정
# 1039 아담스 패밀리 2
# 1040 장르만 로맨스
# 1041 이터널스
# 1042 듄
# 1043 강릉
# 1044 디어 에반 핸슨
# 1045 아담스 패밀리 2
# 1046 프렌치 디스패치
# 1047 귀멸의 칼날: 나타구모산 편
# 1048 뱅드림! 필름 라이브 세컨드 스테이지
# 1049 귀멸의 칼날: 남매의 연
# 1050 장르만 로맨스
# 1051 이터널스
# 1052 듄
# 1053 강릉
# 1054 디어 에반 핸슨
# 1055 아담스 패밀리 2
# 1056 프렌치 디스패치
# 1057 귀멸의 칼날: 나타구모산 편
# 1058 귀멸의 칼날: 남매의 연
# 1059 뱅드림! 필름 라이브 세컨드 스테이지
# 1060 장르만 로맨스
# 1061 이터널스
# 1062 태일이
# 1063 듄
# 1064 강릉
# 1065 디어 에반 핸슨
# 1066 프렌치 디스패치
# 1067 귀멸의 칼날: 나타구모산 편
# 1068 무녀도
# 1069 아담스 패밀리 2
# 1070 장르만 로맨스
# 1071 이터널스
# 1072 태일이
# 1073 듄
# 1074 강릉
# 1075 디어 에반 핸슨
# 1076 프렌치 디스패치
# 1077 귀멸의 칼날: 나타구모산 편
# 1078 너에게 가는 길
# 1079 베놈 2: 렛 데어 비 카니지
# 1080 유체이탈자
# 1081 엔칸토: 마법의 세계
# 1082 연애 빠진 로맨스
# 1083 이터널스
# 1084 장르만 로맨스
# 1085 듄
# 1086 프렌치 디스패치
# 1087 디어 에반 핸슨
# 1088 귀멸의 칼날: 나타구모산 편
# 1089 호빗: 스마우그의 폐허
# 1090 유체이탈자
# 1091 연애 빠진 로맨스
# 1092 엔칸토: 마법의 세계
# 1093 이터널스
# 1094 장르만 로맨스
# 1095 태일이
# 1096 듄
# 1097 프렌치 디스패치
# 1098 뱅드림! 필름 라이브 세컨드 스테이지
# 1099 디어 에반 핸슨
# 1100 유체이탈자
# 1101 엔칸토: 마법의 세계
# 1102 연애 빠진 로맨스
# 1103 이터널스
# 1104 장르만 로맨스
# 1105 듄
# 1106 프렌치 디스패치
# 1107 메이드 인 이태리
# 1108 디어 에반 핸슨
# 1109 강릉
# 1110 유체이탈자
# 1111 엔칸토: 마법의 세계
# 1112 연애 빠진 로맨스
# 1113 이터널스
# 1114 장르만 로맨스
# 1115 듄
# 1116 프렌치 디스패치
# 1117 디어 에반 핸슨
# 1118 뱅드림! 필름 라이브 세컨드 스테이지
# 1119 귀멸의 칼날: 나타구모산 편
# 1120 유체이탈자
# 1121 엔칸토: 마법의 세계
# 1122 연애 빠진 로맨스
# 1123 이터널스
# 1124 장르만 로맨스
# 1125 듄
# 1126 프렌치 디스패치
# 1127 디어 에반 핸슨
# 1128 강릉
# 1129 귀멸의 칼날: 나타구모산 편
# 1130 유체이탈자
# 1131 연애 빠진 로맨스
# 1132 엔칸토: 마법의 세계
# 1133 이터널스
# 1134 장르만 로맨스
# 1135 듄
# 1136 무녀도
# 1137 프렌치 디스패치
# 1138 디어 에반 핸슨
# 1139 태일이
# 1140 유체이탈자
# 1141 연애 빠진 로맨스
# 1142 엔칸토: 마법의 세계
# 1143 이터널스
# 1144 장르만 로맨스
# 1145 듄
# 1146 프렌치 디스패치
# 1147 디어 에반 핸슨
# 1148 강릉
# 1149 메이드 인 이태리
# 1150 유체이탈자
# 1151 연애 빠진 로맨스
# 1152 고스트버스터즈 라이즈
# 1153 엔칸토: 마법의 세계
# 1154 라스트 나잇 인 소호
# 1155 듄
# 1156 태일이
# 1157 귀멸의 칼날: 주합회의·나비저택 편
# 1158 이터널스
# 1159 장르만 로맨스
# 1160 유체이탈자
# 1161 연애 빠진 로맨스
# 1162 엔칸토: 마법의 세계
# 1163 고스트버스터즈 라이즈
# 1164 듄
# 1165 라스트 나잇 인 소호
# 1166 태일이
# 1167 이터널스
# 1168 장르만 로맨스
# 1169 뱅드림! 필름 라이브 세컨드 스테이지
# 1170 유체이탈자
# 1171 연애 빠진 로맨스
# 1172 엔칸토: 마법의 세계
# 1173 고스트버스터즈 라이즈
# 1174 듄
# 1175 라스트 나잇 인 소호
# 1176 이터널스
# 1177 태일이
# 1178 장르만 로맨스
# 1179 귀멸의 칼날: 주합회의·나비저택 편
# 1180 유체이탈자
# 1181 엔칸토: 마법의 세계
# 1182 연애 빠진 로맨스
# 1183 고스트버스터즈 라이즈
# 1184 듄
# 1185 이터널스
# 1186 귀멸의 칼날: 주합회의·나비저택 편
# 1187 라스트 나잇 인 소호
# 1188 태일이
# 1189 장르만 로맨스
# 1190 유체이탈자
# 1191 엔칸토: 마법의 세계
# 1192 연애 빠진 로맨스
# 1193 고스트버스터즈 라이즈
# 1194 듄
# 1195 이터널스
# 1196 라스트 나잇 인 소호
# 1197 태일이
# 1198 장르만 로맨스
# 1199 귀멸의 칼날: 주합회의·나비저택 편
# 1200 유체이탈자
# 1201 연애 빠진 로맨스
# 1202 엔칸토: 마법의 세계
# 1203 듄
# 1204 고스트버스터즈 라이즈
# 1205 라스트 나잇 인 소호
# 1206 이터널스
# 1207 태일이
# 1208 장르만 로맨스
# 1209 킬링 카인드: 킬러의 수제자
# 1210 유체이탈자
# 1211 연애 빠진 로맨스
# 1212 엔칸토: 마법의 세계
# 1213 고스트버스터즈 라이즈
# 1214 듄
# 1215 태일이
# 1216 라스트 나잇 인 소호
# 1217 이터널스
# 1218 장르만 로맨스
# 1219 킬링 카인드: 킬러의 수제자
# 1220 유체이탈자
# 1221 연애 빠진 로맨스
# 1222 돈 룩 업
# 1223 엔칸토: 마법의 세계
# 1224 몬스타엑스 : 더 드리밍
# 1225 듄
# 1226 고스트버스터즈 라이즈
# 1227 태일이
# 1228 이터널스
# 1229 장르만 로맨스
# 1230 유체이탈자
# 1231 연애 빠진 로맨스
# 1232 엔칸토: 마법의 세계
# 1233 돈 룩 업
# 1234 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 1235 몬스타엑스 : 더 드리밍
# 1236 듄
# 1237 리슨
# 1238 고스트버스터즈 라이즈
# 1239 태일이
# 1240 연애 빠진 로맨스
# 1241 유체이탈자
# 1242 엔칸토: 마법의 세계
# 1243 돈 룩 업
# 1244 듄
# 1245 고스트버스터즈 라이즈
# 1246 몬스타엑스 : 더 드리밍
# 1247 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 1248 이터널스
# 1249 마이 뉴욕 다이어리
# 1250 유체이탈자
# 1251 연애 빠진 로맨스
# 1252 엔칸토: 마법의 세계
# 1253 돈 룩 업
# 1254 듄
# 1255 고스트버스터즈 라이즈
# 1256 몬스타엑스 : 더 드리밍
# 1257 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 1258 이터널스
# 1259 태일이
# 1260 연애 빠진 로맨스
# 1261 유체이탈자
# 1262 엔칸토: 마법의 세계
# 1263 돈 룩 업
# 1264 듄
# 1265 고스트버스터즈 라이즈
# 1266 몬스타엑스 : 더 드리밍
# 1267 이터널스
# 1268 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 1269 마이 뉴욕 다이어리
# 1270 유체이탈자
# 1271 연애 빠진 로맨스
# 1272 엔칸토: 마법의 세계
# 1273 돈 룩 업
# 1274 킹메이커
# 1275 듄
# 1276 몬스타엑스 : 더 드리밍
# 1277 이터널스
# 1278 태일이
# 1279 고스트버스터즈 라이즈
# 1280 유체이탈자
# 1281 연애 빠진 로맨스
# 1282 엔칸토: 마법의 세계
# 1283 듄
# 1284 돈 룩 업
# 1285 킹메이커
# 1286 태일이
# 1287 몬스타엑스 : 더 드리밍
# 1288 고스트버스터즈 라이즈
# 1289 이터널스
# 1290 스파이더맨: 노 웨이 홈
# 1291 연애 빠진 로맨스
# 1292 엔칸토: 마법의 세계
# 1293 유체이탈자
# 1294 돈 룩 업
# 1295 태일이
# 1296 아멜리에
# 1297 BIAF2021 부천국제애니메이션페스티벌 기획상영展
# 1298 노웨어 스페셜
# 1299 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 1300 스파이더맨: 노 웨이 홈
# 1301 연애 빠진 로맨스
# 1302 엔칸토: 마법의 세계
# 1303 유체이탈자
# 1304 뱅드림! 필름 라이브 세컨드 스테이지
# 1305 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 1306 돈 룩 업
# 1307 아멜리에
# 1308 태일이
# 1309 티탄
# 1310 스파이더맨: 노 웨이 홈
# 1311 연애 빠진 로맨스
# 1312 엔칸토: 마법의 세계
# 1313 유체이탈자
# 1314 극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아
# 
극장판 바다 탐험대 옥토넛 : 해저동굴 대탈출
# 1989 씽2게더
# 1990 극장판 주술회전 0
# 1991 언차티드
# 1992 안테벨룸
# 1993 인민을 위해 복무하라
# 1994 나이트메어 앨리
# 1995 해적: 도깨비 깃발
# 1996 시라노
# 1997 나일 강의 죽음
# 1998 에이핑크 스페셜 무비 : 혼
# 1999 킹메이커
# 2000 극장판 주술회전 0
# 2001 언차티드
# 2002 안테벨룸
# 2003 인민을 위해 복무하라
# 2004 해적: 도깨비 깃발
# 2005 화양연화
# 2006 나이트메어 앨리
# 2007 시라노
# 2008 킹메이커
# 2009 나일 강의 죽음
# 2010 언차티드
# 2011 극장판 주술회전 0
# 2012 안테벨룸
# 2013 인민을 위해 복무하라
# 2014 해적: 도깨비 깃발
# 2015 나이트메어 앨리
# 2016 시라노
# 2017 나일 강의 죽음
# 2018 킹메이커
# 2019 스파이더맨: 노 웨이 홈
# 2020 언차티드
# 2021 극장판 주술회전 0
# 2022 안테벨룸
# 2023 인민을 위해 복무하라
# 2024 해적: 도깨비 깃발
# 2025 나이트메어 앨리
# 2026 나일 강의 죽음
# 2027 스파이더맨: 노 웨이 홈
# 2028 킹메이커
# 2029 시라노
# 2030 언차티드
# 2031 극장판 주술회전 0
# 2032 안테벨룸
# 2033 인민을 위해 복무하라
# 2034 해적: 도깨비 깃발
# 2035 나이트메어 앨리
# 2036 킹메이커
# 2037 스파이더맨: 노 웨이 홈
# 2038 나일 강의 죽음
# 2039 시라노
# 2040 언차티드
# 2041 극장판 주술회전 0
# 2042 안테벨룸
# 2043 더 배트맨
# 2044 인민을 위해 복무하라
# 2045 해적: 도깨비 깃발
# 2046 나이트메어 앨리
# 2047 스파이더맨: 노 웨이 홈
# 2048 킹메이커
# 2049 나일 강의 죽음
# 2050 더 배트맨
# 2051 언차티드
# 2052 극장판 주술회전 0
# 2053 안테벨룸
# 2054 인민을 위해 복무하라
# 2055 해적: 도깨비 깃발
# 2056 나이트메어 앨리
# 2057 극장판 바다 탐험대 옥토넛 : 해저동굴 대탈출
# 2058 스파이더맨: 노 웨이 홈
# 2059 씽2게더
# 2060 더 배트맨
# 2061 극장판 주술회전 0
# 2062 언차티드
# 2063 이상한 나라의 수학자
# 2064 안테벨룸
# 2065 인민을 위해 복무하라
# 2066 나이트메어 앨리
# 2067 킹메이커
# 2068 해적: 도깨비 깃발
# 2069 나일 강의 죽음
# 2070 더 배트맨
# 2071 극장판 주술회전 0
# 2072 언차티드
# 2073 인민을 위해 복무하라
# 2074 안테벨룸
# 2075 에이핑크 스페셜 무비 : 혼
# 2076 나이트메어 앨리
# 2077 이상한 나라의 수학자
# 2078 나이트 레이더스
# 2079 소피의 세계
# 2080 더 배트맨
# 2081 극장판 주술회전 0
# 2082 언차티드
# 2083 안테벨룸
# 2084 인민을 위해 복무하라
# 2085 해적: 도깨비 깃발
# 2086 나이트메어 앨리
# 2087 스파이더맨: 노 웨이 홈
# 2088 킹메이커
# 2089 에이핑크 스페셜 무비 : 혼
# 2090 더 배트맨
# 2091 극장판 주술회전 0
# 2092 언차티드
# 2093 안테벨룸
# 2094 인민을 위해 복무하라
# 2095 스파이더맨: 노 웨이 홈
# 2096 나이트메어 앨리
# 2097 킹메이커
# 2098 해적: 도깨비 깃발
# 2099 극장판 바다 탐험대 옥토넛 : 해저동굴 대탈출
#
나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션
# 2197 인민을 위해 복무하라
# 2198 스파이더맨: 노 웨이 홈
# 2199 레벤느망
# 2200 문폴
# 2201 이상한 나라의 수학자
# 2202 스펜서
# 2203 더 배트맨
# 2204 극장판 주술회전 0
# 2205 하늘의 푸르름을 아는 사람이여
# 2206 메리 미
# 2207 언차티드
# 2208 뜨거운 피
# 2209 도어맨
# 2210 문폴
# 2211 이상한 나라의 수학자
# 2212 더 배트맨
# 2213 스펜서
# 2214 극장판 주술회전 0
# 2215 메리 미
# 2216 나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션
# 2217 언차티드
# 2218 355
# 2219 하늘의 푸르름을 아는 사람이여
# 2220 문폴
# 2221 이상한 나라의 수학자
# 2222 더 배트맨
# 2223 스펜서
# 2224 극장판 주술회전 0
# 2225 메리 미
# 2226 언차티드
# 2227 하늘의 푸르름을 아는 사람이여
# 2228 안테벨룸
# 2229 도어맨
# 2230 문폴
# 2231 이상한 나라의 수학자
# 2232 더 배트맨
# 2233 스펜서
# 2234 극장판 주술회전 0
# 2235 나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션
# 2236 메리 미
# 2237 언차티드
# 2238 하늘의 푸르름을 아는 사람이여
# 2239 안테벨룸
# 2240 이상한 나라의 수학자
# 2241 문폴
# 2242 더 배트맨
# 2243 스펜서
# 2244 극장판 주술회전 0
# 2245 나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션
# 2246 메리 미
# 2247 언차티드
# 2248 하늘의 푸르름을 아는 사람이여
# 2249 안테벨룸
# 2250 이상한 나라의 수학자
# 2251 문폴
# 2252 더 배트맨
# 2253 스펜서
# 2254 극장판 주술회전 0
# 2255 하늘의 푸르름을 아는 사람이여
# 2256 나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션
# 2257 도어맨
# 2258 킹메이커
# 2259 메리 미
# 2260 이상한 나라의 수학자
# 2261 문폴
# 2262 더 배트맨
# 2263 스펜서
# 2264 에펠
# 2265 극장판 주술회전 0
# 2266 도어맨
# 2267 킹메이커
# 2268 하늘의 푸르름을 아는 사람이여
# 2269 나의 히어로 아카데미아 더 무비: 월드 히어로즈 미션
# 2270 뜨거운 피
# 2271 이상한 나라의 수학자
# 2272 문폴
# 2273 더 배트맨
# 2274 스펜서
# 2275 극장판 주술회전 0
# 2276 벨파스트
# 2277 리디밍 러브
# 2278 하늘의 푸르름을 아는 사람이여
# 2279 에펠
# 2280 뜨거운 피
# 2281 극장판 주술회전 0
# 2282 이상한 나라의 수학자
# 2283 더 배트맨
# 2284 문폴
# 2285 스펜서
# 2286 뱅드림! 팝핀' 드림!
# 2287 벨파스트
# 2288 킹 리차드
# 2289 해적: 도깨비 깃발
# 2290 뜨거운 피
# 2291 이상한 나라의 수학자
# 2292 더 배트맨
# 2293 문폴
# 2294 극장판 주술회전 0
# 2295 스펜서
# 2296 벨파스트
# 2297 뱅드림! 팝핀' 드림!
# 2298 킹 리차드
# 2299 리디밍 러브
# 2300 뜨거운 피
# 2301 이상한 나라의 수학자
# 2302 극장판 주술회전 0
# 2303 더 배트맨
# 2304 문폴
# 2305 스펜서
# 2306 벨파스트
# 2307 킹 리차드
# 2308 뱅드림! 팝핀' 드림!
# 2309 신비한 동물사전
# 2310 뜨거운 피
# 2311 이상한 나라의 수학자
# 2312 더 배트맨
# 2313 문폴
# 2314 극장판 주술회전 0
# 2315 스펜서
# 2316 벨파스트
# 2317 뱅드림! 팝핀' 드림!
# 2318 킹 리차드
# 2319 에펠
# 2320 뜨거운 피
# 2321 이상한 나라의 수학자
# 2322 더 배트맨
# 2323 극장판 주술회전 0
# 2324 문폴
# 2325 스펜서
# 2326 언차티드
# 2327 벨파스트
# 2328 만년이 지나도 변하지 않는 게 있어
# 2329 킹 리차드
# 2330 뜨거운 피
# 2331 이상한 나라의 수학자
# 2332 더 배트맨
# 2333 극장판 주술회전 0
# 2334 문폴
# 2335 스펜서
# 2336 벨파스트
# 2337 킹 리차드
# 2338 스텔라
# 2339 언차티드
# 2340 모비우스
# 2341 뜨거운 피
# 2342 배니싱: 미제사건
# 2343 이상한 나라의 수학자
# 2344 극장판 주술회전 0
# 2345 더 배트맨
# 2346 스펜서
# 2347 극장판 금빛 모자이크 땡큐!!
# 2348 355
# 2349 킹 리차드
# 2350 모비우스
# 2351 뜨거운 피
# 2352 배니싱: 미제사건
# 2353 이상한 나라의 수학자
# 2354 극장판 주술회전 0
# 2355 더 배트맨
# 2356 만년이 지나도 변하지 않는 게 있어
# 2357 극장판 시그널
# 2358 패러렐 마더스
# 2359 스펜서
# 2360 모비우스
# 2361 뜨거운 피
# 2362 배니싱: 미제사건
# 2363 이상한 나라의 수학자
# 2364 더 배트맨
# 2365 극장판 주술회전 0
# 2366 극장판 시그널
# 2367 패러렐 마더스
# 2368 B컷
# 2369 스펜서
# 2370 모비우스
# 2371 뜨거운 피
# 2372 이상한 나라의 수학자
# 2373 극장판 주술회전 0
# 2374 배니싱: 미제사건
# 2375 더 배트맨
# 2376 스펜서
# 2377 패러렐 마더스
# 2378 문폴
# 2379 뱅드림! 팝핀' 드림!
# 2380 모비우스
# 2381 뜨거운 피
# 2382 이상한 나라의 수학자
# 2383 극장판 주술회전 0
# 2384 배니싱: 미제사건
# 2385 더 배트맨
# 2386 스펜서
# 2387 패러렐 마더스
# 2388 문폴
# 2389 드라이
# 2390 모비우스
# 2391 뜨거운 피
# 2392 스텔라
# 2393 이상한 나라의 수학자
# 2394 더 배트맨
# 2395 배니싱: 미제사건
# 2396 극장판 주술회전 0
# 2397 불도저에 탄 소녀
# 2398 시라노
# 2399 스펜서
# 2400 모비우스
# 2401 뜨거운 피
# 2402 이상한 나라의 수학자
# 2403 더 배트맨
# 2404 배니싱: 미제사건
# 2405 극장판 주술회전 0
# 2406 극장판 시그널
# 2407 앰뷸런스
# 2408 패러렐 마더스
# 2409 스펜서
# 2410 앰뷸런스
# 2411 수퍼 소닉2
# 2412 모비우스
# 2413 스텔라
# 2414 루이스 웨인: 사랑을 그린 고양이 화가
# 2415 뜨거운 피
# 2416 극장판 주술회전 0
# 2417 이상한 나라의 수학자
# 2418 극장판 시그널
# 2419 배니싱: 미제사건
# 2420 앰뷸런스
# 2421 모비우스
# 2422 스텔라
# 2423 수퍼 소닉2
# 2424 루이스 웨인: 사랑을 그린 고양이 화가
# 2425 뜨거운 피
# 2426 불도저에 탄 소녀
# 2427 극장판 주술회전 0
# 2428 이상한 나라의 수학자
# 2429 약속의 네버랜드
# 2430 앰뷸런스
# 2431 모비우스
# 2432 수퍼 소닉2
# 2433 스텔라
극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2713 니 부모 얼굴이 보고 싶다
# 2714 신비한 동물들과 덤블도어의 비밀
# 2715 서울괴담
# 2716 수퍼 소닉2
# 2717 배니싱: 미제사건
# 2718 토르: 마법 검의 전설
# 2719 우연과 상상
# 2720 닥터 스트레인지: 대혼돈의 멀티버스
# 2721 배드 가이즈
# 2722 니 부모 얼굴이 보고 싶다
# 2723 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2724 신비한 동물들과 덤블도어의 비밀
# 2725 서울괴담
# 2726 수퍼 소닉2
# 2727 우연과 상상
# 2728 극장판 주술회전 0
# 2729 토르: 마법 검의 전설
# 2730 닥터 스트레인지: 대혼돈의 멀티버스
# 2731 배드 가이즈
# 2732 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2733 니 부모 얼굴이 보고 싶다
# 2734 신비한 동물들과 덤블도어의 비밀
# 2735 서울괴담
# 2736 수퍼 소닉2
# 2737 우연과 상상
# 2738 극장판 주술회전 0
# 2739 토르: 마법 검의 전설
# 2740 닥터 스트레인지: 대혼돈의 멀티버스
# 2741 니 부모 얼굴이 보고 싶다
# 2742 배드 가이즈
# 2743 신비한 동물들과 덤블도어의 비밀
# 2744 서울괴담
# 2745 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2746 우연과 상상
# 2747 광대: 소리꾼
# 2748 앵커
# 2749 공기살인
# 2750 닥터 스트레인지: 대혼돈의 멀티버스
# 2751 니 부모 얼굴이 보고 싶다
# 2752 배드 가이즈
# 2753 신비한 동물들과 덤블도어의 비밀
# 2754 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2755 서울괴담
# 2756 우연과 상상
# 2757 봄날
# 2758 광대: 소리꾼
# 2759 극장판 귀멸의 칼날: 무한열차편
# 2760 닥터 스트레인지: 대혼돈의 멀티버스
# 2761 범죄도시 2
# 2762 민스미트 작전
# 2763 니 부모 얼굴이 보고 싶다
# 2764 배드 가이즈
# 2765 엄마
# 2766 어부바
# 2767 신비한 동물들과 덤블도어의 비밀
# 2768 봄날
# 2769 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2770 닥터 스트레인지: 대혼돈의 멀티버스
# 2771 민스미트 작전
# 2772 니 부모 얼굴이 보고 싶다
# 2773 어부바
# 2774 배드 가이즈
# 2775 신비한 동물들과 덤블도어의 비밀
# 2776 범죄도시 2
# 2777 엄마
# 2778 서울괴담
# 2779 EBS 댄스파티!
# 2780 닥터 스트레인지: 대혼돈의 멀티버스
# 2781 니 부모 얼굴이 보고 싶다
# 2782 배드 가이즈
# 2783 민스미트 작전
# 2784 신비한 동물들과 덤블도어의 비밀
# 2785 엄마
# 2786 어부바
# 2787 서울괴담
# 2788 우연과 상상
# 2789 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2790 닥터 스트레인지: 대혼돈의 멀티버스
# 2791 범죄도시 2
# 2792 배드 가이즈
# 2793 니 부모 얼굴이 보고 싶다
# 2794 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2795 신비한 동물들과 덤블도어의 비밀
# 2796 민스미트 작전
# 2797 엄마
# 2798 서울괴담
# 2799 어부바
# 2800 닥터 스트레인지: 대혼돈의 멀티버스
# 2801 범죄도시 2
# 2802 배드 가이즈
# 2803 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 2804 니 부모 얼굴이 보고 싶다
# 2805 신비한 동물들과 덤블도어의 비밀
# 2806 민스미트 작전
# 2807 서울괴담
# 2808 엄마
# 2809 어부바
# 2810 닥터 스트레인지: 대혼돈의 멀티버스
# 2811 니 부모 얼굴이 보고 싶다
# 2812 배드 가이즈
# 2813 민스미트 작전
# 2814 신비한 동물들과 덤블도어의 비밀
# 2815 어부바
# 2816 엄마
# 2817 서울괴담
# 2818 극장판 엉덩이 탐정: 수플레 섬의 비밀
# 
극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3013 그대가 조국
# 3014 닥터 스트레인지: 대혼돈의 멀티버스
# 3015 특수요원 빼꼼
# 3016 카시오페아
# 3017 애프터 양
# 3018 뜨거운 피: 디 오리지널
# 3019 피는 물보다 진하다
# 3020 범죄도시 2
# 3021 쥬라기 월드: 도미니언
# 3022 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3023 그대가 조국
# 3024 닥터 스트레인지: 대혼돈의 멀티버스
# 3025 특수요원 빼꼼
# 3026 애프터 양
# 3027 카시오페아
# 3028 우연과 상상
# 3029 아치의 노래, 정태춘
# 3030 범죄도시 2
# 3031 쥬라기 월드: 도미니언
# 3032 그대가 조국
# 3033 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3034 닥터 스트레인지: 대혼돈의 멀티버스
# 3035 마녀(魔女) Part2. The Other One
# 3036 애프터 양
# 3037 카시오페아
# 3038 봄날
# 3039 더 컨트랙터
# 3040 브로커
# 3041 범죄도시 2
# 3042 쥬라기 월드: 도미니언
# 3043 그대가 조국
# 3044 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3045 닥터 스트레인지: 대혼돈의 멀티버스
# 3046 애프터 양
# 3047 민스미트 작전
# 3048 배니싱: 미제사건
# 3049 재춘언니
# 3050 범죄도시 2
# 3051 브로커
# 3052 쥬라기 월드: 도미니언
# 3053 그대가 조국
# 3054 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3055 닥터 스트레인지: 대혼돈의 멀티버스
# 3056 탑건: 매버릭
# 3057 안녕하세요
# 3058 어부바
# 3059 니 부모 얼굴이 보고 싶다
# 3060 범죄도시 2
# 3061 브로커
# 3062 쥬라기 월드: 도미니언
# 3063 그대가 조국
# 3064 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3065 닥터 스트레인지: 대혼돈의 멀티버스
# 3066 애프터 양
# 3067 코다
# 3068 스텔라
# 3069 이공삼칠
# 3070 범죄도시 2
# 3071 브로커
# 3072 쥬라기 월드: 도미니언
# 3073 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3074 그대가 조국
# 3075 닥터 스트레인지: 대혼돈의 멀티버스
# 3076 탑건: 매버릭
# 3077 애프터 양
# 3078 이공삼칠
# 3079 베르네 부인의 장미정원
# 3080 범죄도시 2
# 3081 브로커
# 3082 쥬라기 월드: 도미니언
# 3083 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3084 그대가 조국
# 3085 닥터 스트레인지: 대혼돈의 멀티버스
# 3086 탑건: 매버릭
# 3087 애프터 양
# 3088 이공삼칠
# 3089 베르네 부인의 장미정원
# 3090 범죄도시 2
# 3091 브로커
# 3092 쥬라기 월드: 도미니언
# 3093 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3094 닥터 스트레인지: 대혼돈의 멀티버스
# 3095 그대가 조국
# 3096 감동주의보
# 3097 배드 가이즈
# 3098 애프터 양
# 3099 불도저에 탄 소녀
# 3100 범죄도시 2
# 3101 브로커
# 3102 쥬라기 월드: 도미니언
# 3103 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3104 그대가 조국
# 3105 닥터 스트레인지: 대혼돈의 멀티버스
# 3106 버즈 라이트이어
# 3107 애프터 양
# 3108 니얼굴
# 3109 이공삼칠
# 3110 마녀(魔女) Part2. The Other One
# 3111 범죄도시 2
# 3112 브로커
# 3113 버즈 라이트이어
# 3114 쥬라기 월드: 도미니언
# 3115 배드 가이즈
# 3116 수퍼 소닉2
# 3117 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3118 불도저에 탄 소녀
# 3119 실종
# 3120 마녀(魔女) Part2. The Other One
# 3121 범죄도시 2
# 3122 브로커
# 3123 버즈 라이트이어
# 3124 쥬라기 월드: 도미니언
# 3125 그대가 조국
# 3126 탑건: 매버릭
# 3127 룸 쉐어링
# 3128 경아의 딸
# 3129 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3130 마녀(魔女) Part2. The Other One
# 3131 범죄도시 2
# 3132 브로커
# 3133 버즈 라이트이어
# 3134 쥬라기 월드: 도미니언
# 3135 모비우스
# 3136 실종
# 3137 앵커
# 3138 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3139 극장판 금빛 모자이크 땡큐!!
# 3140 마녀(魔女) Part2. The Other One
# 3141 범죄도시 2
# 3142 버즈 라이트이어
# 3143 브로커
# 3144 쥬라기 월드: 도미니언
# 3145 탑건: 매버릭
# 3146 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3147 닥터 스트레인지: 대혼돈의 멀티버스
# 3148 그대가 조국
# 3149 애프터 양
# 3150 마녀(魔女) Part2. The Other One
# 3151 범죄도시 2
# 3152 버즈 라이트이어
# 3153 브로커
# 3154 쥬라기 월드: 도미니언
# 3155 탑건: 매버릭
# 3156 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3157 닥터 스트레인지: 대혼돈의 멀티버스
# 3158 그대가 조국
# 3159 실종
# 3160 마녀(魔女) Part2. The Other One
# 3161 범죄도시 2
# 3162 브로커
# 3163 버즈 라이트이어
# 3164 쥬라기 월드: 도미니언
# 3165 룸 쉐어링
# 3166 닥터 스트레인지: 대혼돈의 멀티버스
# 3167 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3168 실종
# 3169 공기살인
# 3170 마녀(魔女) Part2. The Other One
# 3171 범죄도시 2
# 3172 브로커
# 3173 버즈 라이트이어
# 3174 쥬라기 월드: 도미니언
# 3175 헤어질 결심
# 3176 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3177 실종
# 3178 닥터 스트레인지: 대혼돈의 멀티버스
# 3179 신비한 동물들과 덤블도어의 비밀
# 3180 탑건: 매버릭
# 3181 마녀(魔女) Part2. The Other One
# 3182 범죄도시 2
# 3183 브로커
# 3184 버즈 라이트이어
# 3185 쥬라기 월드: 도미니언
# 3186 룸 쉐어링
# 3187 니 부모 얼굴이 보고 싶다
# 3188 뜨거운 피
# 3189 로스트 시티
# 3190 탑건: 매버릭
# 3191 마녀(魔女) Part2. The Other One
# 3192 범죄도시 2
# 3193 브로커
# 3194 버즈 라이트이어
# 3195 헤어질 결심
# 3196 쥬라기 월드: 도미니언
# 3197 모어
# 3198 극장판 윌벤져스 : 수상한 캠핑 대소동
# 3199 룸 쉐어링
# 3200 탑건: 매버릭
# 3201 마녀(魔女) Part2. The Other One
# 3202 범죄도시 2
# 3203 브로커
# 3204 버즈 라이트이어
# 3205 쥬라기 월드: 도미니언
# 3206 룸 쉐어링
# 3207 로스트 시티
# 3208 극장판 윌벤져스 : 수상한 캠핑 대소동
# 3209 니 부모 얼굴이 보고 싶다
# 3210 탑건: 매버릭
# 3211 마녀(魔女) Part2. The Other One
# 3212 범죄도시 2
# 3213 버즈 라이트이어
# 3214 브로커
# 3215 쥬라기 월드: 도미니언
# 3216 극장판 윌벤져스 : 수상한 캠핑 대소동
# 3217 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3218 니 부모 얼굴이 보고 싶다
# 3219 룸 쉐어링
# 3220 탑건: 매버릭
# 3221 마녀(魔女) Part2. The Other One
# 3222 범죄도시 2
# 3223 버즈 라이트이어
# 3224 브로커
# 3225 쥬라기 월드: 도미니언
# 3226 극장판 윌벤져스 : 수상한 캠핑 대소동
# 3227 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3228 니 부모 얼굴이 보고 싶다
# 3229 룸 쉐어링
# 3230 탑건: 매버릭
# 3231 마녀(魔女) Part2. The Other One
# 3232 범죄도시 2
# 3233 브로커
# 3234 쥬라기 월드: 도미니언
# 3235 버즈 라이트이어
# 3236 애프터 양
# 3237 실종
# 3238 카시오페아
# 3239 룸 쉐어링
# 3240 탑건: 매버릭
# 3241 마녀(魔女) Part2. The Other One
# 3242 범죄도시 2
# 3243 브로커
# 3244 쥬라기 월드: 도미니언
# 3245 버즈 라이트이어
# 3246 애프터 양
# 3247 룸 쉐어링
# 3248 실종
# 3249 카시오페아
# 3250 탑건: 매버릭
# 3251 헤어질 결심
# 3252 마녀(魔女) Part2. The Other One
# 3253 범죄도시 2
# 3254 브로커
# 3255 버즈 라이트이어
# 3256 쥬라기 월드: 도미니언
# 3257 위대한 침묵
# 3258 미친 능력
# 3259 토르: 러브 앤 썬더
# 3260 탑건: 매버릭
# 3261 헤어질 결심
# 3262 마녀(魔女) Part2. The Other One
# 3263 범죄도시 2
# 3264 버즈 라이트이어
# 3265 브로커
# 3266 프리! 더 파이널 스트로크 후편
# 3267 컴온 컴온
# 3268 위대한 침묵
# 3269 비욘드 라이브 더 무비 : 샤이니 월드
# 3270 탑건: 매버릭
# 3271 헤어질 결심
# 3272 마녀(魔女) Part2. The Other One
# 3273 범죄도시 2
# 3274 버즈 라이트이어
# 3275 브로커
# 3276 위대한 침묵
# 3277 컴온 컴온
# 3278 쥬라기 월드: 도미니언
# 3279 비욘드 라이브 더 무비 : 샤이니 월드
# 3280 탑건: 매버릭
# 3281 헤어질 결심
# 3282 마녀(魔女) Part2. The Other One
# 3283 범죄도시 2
# 3284 버즈 라이트이어
# 3285 쥬라기 월드: 도미니언
# 3286 극장판 윌벤져스 : 수상한 캠핑 대소동
# 3287 브로커
# 3288 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3289 컴온 컴온
# 3290 탑건: 매버릭
# 3291 헤어질 결심
# 3292 마녀(魔女) Part2. The Other One
# 3293 범죄도시 2
# 3294 버즈 라이트이어
# 3295 극장판 윌벤져스 : 수상한 캠핑 대소동
# 3296 쥬라기 월드: 도미니언
# 3297 극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미
# 3298 브로커
# 3299 컴온 컴온
# 3300 탑건: 매버릭
# 3301 헤어질 결심
# 3302 범죄도시 2
# 3303 마녀(魔女) Part2. The Other One
# 3304 브로커
# 3305 버즈 라이트이어
# 3306 쥬라기 월드: 도미니언
# 3307 컴온 컴온
# 3308 위대한 침묵
# 3309 니얼굴
# 3310 탑건: 매버릭
# 3311 헤어질 결심
# 3312 마녀(魔女) Part2. The Other One
# 3313 범죄도시 2
# 3314 브로커
# 3315 버즈 라이트이어
# 3316 토르: 러브 앤 썬더
# 3317 그대가 조국
# 3318 컴온 컴온
# 3319 위대한 침묵
# 3320 토르: 러브 앤 썬더
# 3321 탑건: 매버릭
# 3322 헤어질 결심
# 3323 범죄도시 2
# 3324 마녀(魔女) Part2. The Other One
# 3325 빅샤크4: 바다공룡 대모험
# 3326 브로커
# 3327 버즈 라이트이어
# 3328 큐어
# 3329 경아의 딸
# 3330 토르: 러브 앤 썬더
# 3331 탑건: 매버릭
# 3332 헤어질 결심
# 3333 범죄도시 2
# 3334 마녀(魔女) Part2. The Other One
# 3335 빅샤크4: 바다공룡 대모험
# 3336 프리! 더 파이널 스트로크 후편
# 3337 큐어
# 3338 BIFAN2022 부천 초이스: 단편 1
# 3339 BIFAN2022 부천 초이스: 단편 2
# 3340 토르: 러브 앤 썬더
# 3341 탑건: 매버릭
# 3342 헤어질 결심
# 3343 범죄도시 2
# 3344 마녀(魔女) Part2. The Other One
# 3345 빅샤크4: 바다공룡 대모험
# 3346 큐어
# 3347 BIFAN2022 부천 초이스: 단편 1
# 3348 BIFAN2022 부천 초이스: 단편 2
# 3349 그대가 조국
# 3350 토르: 러브 앤 썬더
# 3351 탑건: 매버릭
# 3352 헤어질 결심
# 3353 범죄도시 2
# 3354 마녀(魔女) Part2. The Other One
# 3355 빅샤크4: 바다공룡 대모험
# 3356 큐어
# 3357 BIFAN2022 부천 초이스: 단편 1
# 3358 BIFAN2022 부천 초이스: 단편 2
# 3359 BIFAN2022 엑스라지 3
# 3360 토르: 러브 앤 썬더
# 3361 탑건: 매버릭
# 3362 헤어질 결심
# 3363 범죄도시 2
# 3364 마녀(魔女) Part2. The Other One
# 3365 빅샤크4: 바다공룡 대모험
# 3366 큐어
# 3367 버즈 라이트이어
# 3368 BIFAN2022 부천 초이스: 단편 2
# 3369 BIFAN2022 부천 초이스: 단편 1
# 3370 토르: 러브 앤 썬더
# 3371 탑건: 매버릭
# 3372 헤어질 결심
# 3373 범죄도시 2
# 3374 마녀(魔女) Part2. The Other One
# 3375 빅샤크4: 바다공룡 대모험
# 3376 BIFAN2022 부천 초이스: 단편 1
# 3377 BIFAN2022 엑스라지 4
# 3378 큐어
# 3379 더 킬러: 죽어도 되는 아이
# 3380 탑건: 매버릭
# 3381 토르: 러브 앤 썬더
# 3382 헤어질 결심
# 3383 범죄도시 2
# 3384 마녀(魔女) Part2. The Other One
# 3385 빅샤크4: 바다공룡 대모험
# 3386 BIFAN2022 부천 초이스: 단편 1
# 3387 큐어
# 3388 BIFAN2022 엑스라지 4
# 3389 브로커
# 3390 탑건: 매버릭
# 3391 토르: 러브 앤 썬더
# 3392 명탐정 코난: 할로윈의 신부
# 3393 헤어질 결심
# 3394 엘비스
# 3395 더 킬러: 죽어도 되는 아이
# 3396 뒤틀린 집
# 3397 범죄도시 2
# 3398 버즈 라이트이어
# 3399 마녀(魔女) Part2. The Other One
# 3400 탑건: 매버릭
# 3401 토르: 러브 앤 썬더
# 3402 헤어질 결심
# 3403 명탐정 코난: 할로윈의 신부
# 3404 엘비스
# 3405 더 킬러: 죽어도 되는 아이
# 3406 범죄도시 2
# 3407 뒤틀린 집
# 3408 그레이 맨
# 3409 빅샤크4: 바다공룡 대모험
# 3410 탑건: 매버릭
# 3411 토르: 러브 앤 썬더
# 3412 헤어질 결심
# 3413 명탐정 코난: 할로윈의 신부
# 3414 엘비스
# 3415 범죄도시 2
# 3416 더 킬러: 죽어도 되는 아이
# 3417 뒤틀린 집
# 3418 그레이 맨
# 3419 마녀(魔女) Part2. The Other One
# 3420 탑건: 매버릭
# 3421 토르: 러브 앤 썬더
# 3422 헤어질 결심
# 3423 명탐정 코난: 할로윈의 신부
# 3424 범죄도시 2
# 3425 엘비스
# 3426 더 킬러: 죽어도 되는 아이
# 3427 뒤틀린 집
# 3428 그레이 맨
# 3429 마녀(魔女) Part2. The Other One
# 3430 탑건: 매버릭
# 3431 토르: 러브 앤 썬더
# 3432 헤어질 결심
# 3433 명탐정 코난: 할로윈의 신부
# 3434 범죄도시 2
# 3435 엘비스
# 3436 더 킬러: 죽어도 되는 아이
# 3437 뒤틀린 집
# 3438 그레이 맨
# 3439 빅샤크4: 바다공룡 대모험
# 3440 탑건: 매버릭
# 3441 토르: 러브 앤 썬더
# 3442 헤어질 결심
# 3443 명탐정 코난: 할로윈의 신부
# 3444 범죄도시 2
# 3445 엘비스
# 3446 더 킬러: 죽어도 되는 아이
# 3447 외계+인 1부
# 3448 뒤틀린 집
# 3449 그레이 맨
# 3450 탑건: 매버릭
# 3451 토르: 러브 앤 썬더
# 3452 헤어질 결심
# 3453 명탐정 코난: 할로윈의 신부
# 3454 엘비스
# 3455 범죄도시 2
# 3456 더 킬러: 죽어도 되는 아이
# 3457 뒤틀린 집
# 3458 그레이 맨
# 3459 한산: 용의 출현
# 3460 외계+인 1부
# 3461 미니언즈2
# 3462 탑건: 매버릭
# 3463 헤어질 결심
# 3464 토르: 러브 앤 썬더
# 3465 명탐정 코난: 할로윈의 신부
# 3466 썸머 필름을 타고!
# 3467 컴온 컴온
# 3468 범죄도시 2
# 3469 엘비스
# 3470 외계+인 1부
# 3471 미니언즈2
# 3472 탑건: 매버릭
# 3473 헤어질 결심
# 3474 토르: 러브 앤 썬더
# 3475 명탐정 코난: 할로윈의 신부
# 3476 범죄도시 2
# 3477 썸머 필름을 타고!
# 3478 엘비스
# 3479 아이언 크로스: 노르망디 상륙작전
# 3480 외계+인 1부
# 3481 미니언즈2
# 3482 탑건: 매버릭
# 3483 헤어질 결심
# 3484 명탐정 코난: 할로윈의 신부
# 3485 토르: 러브 앤 썬더
# 3486 범죄도시 2
# 3487 썸머 필름을 타고!
# 3488 엘비스
# 3489 그레이 맨
# 3490 외계+인 1부
# 3491 미니언즈2
# 3492 탑건: 매버릭
# 3493 헤어질 결심
# 3494 토르: 러브 앤 썬더
# 3495 명탐정 코난: 할로윈의 신부
# 3496 범죄도시 2
# 3497 엘비스
# 3498 썸머 필름을 타고!
# 3499 한산: 용의 출현
# 3500 외계+인 1부
# 3501 미니언즈2
# 3502 탑건: 매버릭
# 3503 헤어질 결심
# 3504 토르: 러브 앤 썬더
# 3505 명탐정 코난: 할로윈의 신부
# 3506 범죄도시 2
# 3507 엘비스
# 3508 썸머 필름을 타고!
# 3509 한산: 용의 출현
# 3510 외계+인 1부
# 3511 미니언즈2
# 3512 탑건: 매버릭
# 3513 헤어질 결심
# 3514 명탐정 코난: 할로윈의 신부
# 3515 토르: 러브 앤 썬더
# 3516 비상선언
# 3517 한산: 용의 출현
# 3518 범죄도시 2
# 3519 엘비스
# 3520 미니언즈2
# 3521 외계+인 1부
# 3522 탑건: 매버릭
# 3523 헤어질 결심
# 3524 명탐정 코난: 할로윈의 신부
# 3525 토르: 러브 앤 썬더
# 3526 비상선언
# 3527 멘
# 3528 한산: 용의 출현
# 3529 엘비스
# 3530 한산: 용의 출현
# 3531 미니언즈2
# 3532 탑건: 매버릭
# 3533 외계+인 1부
# 3534 헤어질 결심
# 3535 명탐정 코난: 할로윈의 신부
# 3536 썸머 필름을 타고!
# 3537 토르: 러브 앤 썬더
# 3538 더 킬러: 죽어도 되는 아이
# 3539 헌트
# 3540 한산: 용의 출현
# 3541 미니언즈2
# 3542 탑건: 매버릭
# 3543 뽀로로 극장판 드래곤캐슬 대모험
# 3544 외계+인 1부
# 3545 헤어질 결심
# 3546 명탐정 코난: 할로윈의 신부
# 3547 프리! 더 파이널 스트로크 후편
# 3548 비욘드 라이브 더 무비: 엑소의 사다리 타고 세계여행3
# 3549 토르: 러브 앤 썬더
# 3550 한산: 용의 출현
# 3551 미니언즈2
# 3552 탑건: 매버릭
# 3553 외계+인 1부
# 3554 뽀로로 극장판 드래곤캐슬 대모험
# 3555 헤어질 결심
# 3556 명탐정 코난: 할로윈의 신부
# 3557 토르: 러브 앤 썬더
# 3558 비욘드 라이브 더 무비: 엑소의 사다리 타고 세계여행3
# 3559 썸머 필름을 타고!
# 3560 한산: 용의 출현
# 3561 미니언즈2
# 3562 탑건: 매버릭
# 3563 외계+인 1부
# 3564 뽀로로 극장판 드래곤캐슬 대모험
# 3565 헤어질 결심
# 3566 명탐정 코난: 할로윈의 신부
# 3567 토르: 러브 앤 썬더
# 3568 비상선언
# 3569 엘비스
# 3570 한산: 용의 출현
# 3571 미니언즈2
# 3572 탑건: 매버릭
# 3573 외계+인 1부
# 3574 뽀로로 극장판 드래곤캐슬 대모험
# 3575 헤어질 결심
# 3576 명탐정 코난: 할로윈의 신부
# 3577 비상선언
# 3578 토르: 러브 앤 썬더
# 3579 엘비스
# 3580 한산: 용의 출현
# 3581 미니언즈2
# 3582 탑건: 매버릭
# 3583 뽀로로 극장판 드래곤캐슬 대모험
# 3584 외계+인 1부
# 3585 헤어질 결심
# 3586 명탐정 코난: 할로윈의 신부
# 3587 비상선언
# 3588 헌트
# 3589 토르: 러브 앤 썬더
# 3590 한산: 용의 출현
# 3591 미니언즈2
# 3592 탑건: 매버릭
# 3593 뽀로로 극장판 드래곤캐슬 대모험
# 3594 외계+인 1부
# 3595 헤어질 결심
# 3596 명탐정 코난: 할로윈의 신부
# 3597 헌트
# 3598 비상선언
# 3599 토르: 러브 앤 썬더
# 3600 비상선언
# 3601 한산: 용의 출현
# 3602 미니언즈2
# 3603 탑건: 매버릭
# 3604 뽀로로 극장판 드래곤캐슬 대모험
# 3605 외계+인 1부
# 3606 헤어질 결심
# 3607 극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021
# 3608 명탐정 코난: 할로윈의 신부
# 3609 썸머 필름을 타고!
# 3610 비상선언
# 3611 한산: 용의 출현
# 3612 미니언즈2
# 3613 탑건: 매버릭
# 3614 뽀로로 극장판 드래곤캐슬 대모험
# 3615 헤어질 결심
# 3616 외계+인 1부
# 3617 극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021
# 3618 명탐정 코난: 할로윈의 신부
# 3619 프리! 더 파이널 스트로크 후편
# 3620 한산: 용의 출현
# 3621 비상선언
# 3622 탑건: 매버릭
# 3623 미니언즈2
# 3624 뽀로로 극장판 드래곤캐슬 대모험
# 3625 헤어질 결심
# 3626 외계+인 1부
# 3627 극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021
# 3628 명탐정 코난: 할로윈의 신부
# 3629 마녀(魔女) Part2. The Other One
# 3630 한산: 용의 출현
# 3631 비상선언
# 3632 탑건: 매버릭
# 3633 미니언즈2
# 3634 뽀로로 극장판 드래곤캐슬 대모험
# 3635 외계+인 1부
# 3636 헤어질 결심
# 3637 극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021
# 3638 명탐정 코난: 할로윈의 신부
# 3639 헌트
# 3640 한산: 용의 출현
# 3641 비상선언
# 3642 탑건: 매버릭
# 3643 미니언즈2
# 3644 뽀로로 극장판 드래곤캐슬 대모험
# 3645 헤어질 결심
# 3646 외계+인 1부
# 3647 극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021
# 3648 명탐정 코난: 할로윈의 신부
# 3649 헌트

# %%
merged_data['openDt'][merged_data['openDt'] == ' '] = '1900-01-01'
# Out:
# C:\Users\22tka\AppData\Local\Temp\ipykernel_24536\790757223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data['openDt'][merged_data['openDt'] == ' '] = '1900-01-01'

# %%
# 특정 요소에 특정한 문자가 포함되었는지는
# .str.contains("조회문자") 형식으로 확인 가능합니다.
target_rnum = merged_data[['rnum','movieNm']][merged_data['movieNm'].str.contains("'")].index

# %%
# 위의 방식으로 우리가 수정해야할 movieNm의 인덱스번호만 얻어올 수 있음
target_rnum = merged_data[['rnum','movieNm']][merged_data['movieNm'].str.contains("'")].index
# Out:
#       index rnum rank rankInten rankOldAndNew   movieCd  \
# 0         0    1    1         0           OLD  20204117
# 1         1    2    2         0           OLD  20217845
# 2         2    3    3         0           OLD  20218391
# 3         3    4    4         0           OLD  20191951
# 4         4    5    5         0           OLD  20218875
# ...     ...  ...  ...       ...           ...       ...
# 3645      5    6    6         1           OLD  20209654
# 3646      6    7    7        -1           OLD  20208446
# 3647      7    8    8         0           OLD  20226107
# 3648      8    9    9         0           OLD  20225237
# 3649      9   10   10         0           OLD  20211792
#
#                               movieNm      openDt    salesAmt salesShare  \
# 0                                모가디슈  2021-07-28  2000829380       56.5
# 1                         더 수어사이드 스쿼드  2021-08-04   676797240       19.1
# 2                            보스 베이비 2  2021-07-21   284206020        8.0
# 3                              블랙 위도우  2021-07-07   194489780        5.5
# 4                   극장판 도라에몽: 진구의 신공룡  2021-08-05    88917620        2.5
# ...                               ...         ...         ...        ...
# 3645                           헤어질 결심  2022-06-29   169174033        1.7
# 3646                          외계+인 1부  2022-07-20   123965118        1.3
# 3647  극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021  2022-08-03    77727199        0.8
# 3648                  명탐정 코난: 할로윈의 신부  2022-07-13    44635198        0.5
# 3649                               헌트  2022-08-10    29793598        0.3
#
#       salesInten salesChange     salesAcc  audiCnt audiInten audiChange  \
# 0       38859180           2  16579074530   196672      4041        2.1
# 1     -127499190       -15.9   2942253950    63095    -12197      -16.2
# 2        1506480         0.5   7511398580    30046       108        0.4
# 3      -28197330       -12.7  29457331370    18740     -2673      -12.5
# 4       -4415810        -4.7    337195080     9837      -612       -5.9
# ...          ...         ...          ...      ...       ...        ...
# 3645   -32677140       -16.2  18385204948    15203     -2798      -15.5
# 3646   -98324419       -44.2  15629862451    11690     -7177        -38
# 3647     2170399         2.9    346253298     7903       248        3.2
# 3648      623298         1.4   4598589872     4122        13        0.3
# 3649    -2295602        -7.2    165546798     2377      -166       -6.5
#
#       audiAcc  scrnCnt showCnt      date
# 0     1712375     1639    6757  20210808
# 1      281377     1033    3306  20210808
# 2      836805      777    1654  20210808
# 3     2908679      540     924  20210808
# 4       38669      502     781  20210808
# ...       ...      ...     ...       ...
# 3645  1775050      266     426  20220807
# 3646  1496935      374     499  20220807
# 3647    36417      357     466  20220807
# 3648   442570       91     115  20220807
# 3649    16573       12      13  20220807
#
# [3650 rows x 20 columns]

# %%
merged_data.iloc[i]['movieNm'] = merged_data['movieNm'][merged_data['movieNm'].str.contains("'").str.replace("'", " ")

# %%
# apply()를 이용한 전처리
# .apply()는 데이터프레임에 적용해서, 사용자가 전처리 형식을 직접 지정해 적용할 수 있도록 도와줍니다.
# 함수를 이용해 처리합니다.
# 지금같은경우, '가 포함된 문자열을 '를 제거한 형태로 바꾸려 하므로 해당 로직을 함수로 만들어 저장하고
# 그 다음 적용하고 싶은 컬럼에 .apply()를 걸어 적용하면 됩니다.

# %%
# 요소를 읽어서. '가 포함된 경우 삭제한 다음 리턴하는 함수 작성
def deletion_char(target):
    return target.replace("'", "")

# %%
# 함수가 만들어졌으면, 수정해줄 컬럼을 지정하고, 거기에 apply()를 쓴 다음 함수명을 내부에 파라미터로 줍니다.
merged_data['movieNm'] = merged_data['movieNm'].apply(deletion_char)

# %%
merged_data.iloc[target_rnum]
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd    movieNm      openDt  \
# 6    7    7         0           OLD  20202185    방법: 재차의  2021-07-28
# 7    8    8         3           OLD  20218815  블랙핑크 더 무비  2021-08-04
# 8    9    9        -1           OLD  20218834     그린 나이트  2021-08-05
# 7    8    8         3           OLD  20218815  블랙핑크 더 무비  2021-08-04
# 9   10   10        -1           OLD  20218364         랑종  2021-07-14
#
#    salesAmt salesShare salesInten salesChange    salesAcc  audiCnt audiInten  \
# 6  52498390        1.5    -291180        -0.6  1476515330     5122       -36
# 7  41201000        1.2   24823500       151.6   154036500     3081      1821
# 8  18395790        0.5   -6726620       -26.8   100309010     1855      -610
# 7  41201000        1.2   24823500       151.6   154036500     3081      1821
# 9  16745020        0.5   -3988320       -19.2  8586730770     1508      -379
#
#   audiChange audiAcc  scrnCnt showCnt      date
# 6       -0.7  165954      351     427  20210808
# 7      144.5   11761      147     194  20210808
# 8      -24.7   10904      201     234  20210808
# 7      144.5   11761      147     194  20210808
# 9      -20.1  827673       76     105  20210808

# %%
# apply로 또 해결합니다.
def set_date(target):
    if(target == ' '):
        return '1900-01-01'
    return target

# %%
con.commit()

# %%
cur.execute("SELECT * FROM movie_tbl")
movie_tbl = cur.fetchall()

# %%
pd.DataFrame(movie_tbl)

# %%
# Oracle 연동
import cx_Oracle
# 11버전은 localhost:1521/XE
# 18버전은 localhost:1521/XEPDB1
con_oracle = cx_Oracle.connect("mytest", "mytest", "localhost:1521/XEPDB1")

# %%
# 커서 얻어온 뒤부터는 mysql과 동일하게 cur.fetchall() 등을 이용해 처리할 수 있음.
cur_oracle = con_oracle.cursor()

# %%
# oracle을 켜서 테이블을 똑같이 만들어주시고, 위의 mysql로직에서 얻어온 merged_data를 역시
# oracle DB에도 적재해주시고 다시 꺼내서 DataFrame화를 시켜주시면 됩니다.
# 위의 반복문 코드를 응용해 전체 데이터를 다 DB에 넣고 확인해주세요.
for i in range(len(merged_data)):
    selected_data = merged_data.iloc[i]
    cur_oracle.execute("INSERT INTO movie_tbl VALUES (movieNum.nextval, '%s', '%s', %s, %s, '%s')" % (selected_data['movieNm'], selected_data['openDt'], selected_data['audiCnt'], selected_data['showCnt'], selected_data['date']))

# %%
con_oracle.commit()

# %%
cur_oracle.execute("SELECT * FROM movie_tbl")
movie_tbl = cur_oracle.fetchall()
movie_db_data = pd.DataFrame(movie_tbl)

# %%
movie_db_data.columns = ['rnum', 'movieNm', 'openDt', 'audiCnt', 'showcnt', 'dataDate']

# %%
movie_db_data
# Out:
#       rnum                          movieNm     openDt  audiCnt  showcnt  \
# 0        1                             모가디슈 2021-07-28   196672     6757
# 1        2                      더 수어사이드 스쿼드 2021-08-04    63095     3306
# 2        3                         보스 베이비 2 2021-07-21    30046     1654
# 3        4                           블랙 위도우 2021-07-07    18740      924
# 4        5                극장판 도라에몽: 진구의 신공룡 2021-08-05     9837      781
# ...    ...                              ...        ...      ...      ...
# 3645  3646                           헤어질 결심 2022-06-29    15203      426
# 3646  3647                          외계+인 1부 2022-07-20    11690      499
# 3647  3648  극장판 도라에몽: 진구의 우주소전쟁 리틀스타워즈 2021 2022-08-03     7903      466
# 3648  3649                  명탐정 코난: 할로윈의 신부 2022-07-13     4122      115
# 3649  3650                               헌트 2022-08-10     2377       13
#
#        dataDate
# 0    2021-08-08
# 1    2021-08-08
# 2    2021-08-08
# 3    2021-08-08
# 4    2021-08-08
# ...         ...
# 3645 2022-08-07
# 3646 2022-08-07
# 3647 2022-08-07
# 3648 2022-08-07
# 3649 2022-08-07
#
# [3650 rows x 6 columns]
